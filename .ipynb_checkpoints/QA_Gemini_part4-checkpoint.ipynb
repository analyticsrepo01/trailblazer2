# %% [markdown]
# ### Installation of required libs for Gemini and PaLM

# %%
# !pip install streamlit

# %%
# !pip install --upgrade google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /home/jupyter/.local/lib/python3.10/site-packages (1.40.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.34.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.13.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.61.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.25.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2023.11.17)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)

# %%
# !pip install --upgrade google-cloud-aiplatform
GCP_PROJECT= PROJECT_ID=project_id='my-project-0004-346516'
LOCATION = REGION = 'us-central1'
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /home/jupyter/.local/lib/python3.10/site-packages (1.40.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.34.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.61.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0dev,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.25.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2023.7.22)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)

# %% [markdown]
# ### Vertex AI setup

# %%
import os

# import streamlit as st
import vertexai
from vertexai.preview.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)


# @st.cache_resource
def get_model():
    generation_model = TextGenerationModel.from_pretrained("text-bison@002")
    return generation_model


def get_text_generation(prompt="", **parameters):
    generation_model = get_model()
    response = generation_model.predict(prompt=prompt, **parameters)

    return response.text

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part

# input_prompt = """can you give me details of paracetamol"""

def generate(input_prompt):
    model = GenerativeModel("gemini-ultra")
    responses = model.generate_content(
        input_prompt ,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1,
        "top_k": 32
    },
        safety_settings=[],
        stream=True,
    )
    
    all_response  = []
    
    for response in responses:
        # print(response.text, end="")
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))
    

def generate_pro(input_prompt):
    model = GenerativeModel("gemini-pro")
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1
    },stream=True,)
    
    all_response  = []
    
    for response in responses:
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 1,
    "top_k": 40
}

def generate_palm_unicorn_v1(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-unicorn@001")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

def generate_palm_bison32k(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-bison-32k")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

# %%
input_prompt = "What are the symptoms of influenza?" 

# generate_pro(input_prompt)
# generate_palm_unicorn_v1(input_prompt)
# generate_palm_bison32k(input_prompt)

# %%
# !ls
# Out:
# '$BUCKET_URI'				  questions-Copy1.json
#  RAG_on_DBCreated_part3.ipynb		  questions.json
#  Testing_Gemini+Palm_models_part4.ipynb   questions_2.json
#  Winnie_the_Pooh_3_Pages.pdf		 'reading pdf_part1.ipynb'
#  diapers.png				 'reading pdf_part2.ipynb'
#  harry_potte_qa.csv			  requirement2.txt
#  product-embs.json			  requirements.txt

# %% [markdown]
# ### Read the Q&A file

# %% [markdown]
# #### This uses the file from Matching Engine which has questions and retrieved document results

# %%
import pandas as pd
filename = "./harry_potte_qa_output.csv"
df_qa = pd.read_csv(filename, sep ="|")

# print(df_qa.head(1))
System_Prompts = """ You are an expert in reading harry potter books, but only provide evidences from the information provide and do not use an other information
so here are some search results : 
"""

Question_Prompts = """ -- Based on information above help to answer following user question
"""

df_qa['combine_prompt_RAG1'] = System_Prompts + ' ' +df_qa['pagewise_texts_v1'] + ' Question_Prompts : '+ df_qa['Question'] 
df_qa['combine_prompt_RAG2'] = System_Prompts + ' ' +df_qa['pagewise_texts_v2'] + ' Question_Prompts : '+ df_qa['Question'] 
df_qa['combine_prompt_RAG3'] = System_Prompts + ' ' +df_qa['pagewise_texts_v3'] + ' Question_Prompts : '+ df_qa['Question'] 


# print(df['System Prompts'], df['RAG Results'] ,df['User Question'] )
# print(selected_column[0])

# %%
# generate_medlpalm(df.loc[0 ,'combine_prompt'])

# %%
for i in range(0, len(df_qa)):

    if i<=100:
        # df['Gemini_ultra_model_output'][i] = generate(df['combine_prompt'][i])
        print("iteration #", i)

    df_qa.loc[i, "Gemini_pro_model_output_v1"] = generate_pro(df_qa.loc[i,'combine_prompt_RAG1'])
    df_qa.loc[i, "Gemini_pro_model_output_v2"] = generate_pro(df_qa.loc[i,'combine_prompt_RAG2'])
    df_qa.loc[i, "Gemini_pro_model_output_v3"] = generate_pro(df_qa.loc[i,'combine_prompt_RAG3'])

    # df.loc[i, "medLM_model_output"] = generate_medllms_v1(df.loc[i,'combine_prompt'])
    df_qa.loc[i, "palm_bison32k_output_v1"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG1'])
    df_qa.loc[i, "palm_bison32k_output_v2"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG2'])
    df_qa.loc[i, "palm_bison32k_output_v3"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG3'])

# generate_medllms_v1(input_prompt)
# generate_palm_unicorn_v1(input_prompt)
# input_prompt = "What are the symptoms of influenza?" 
# generate_medlpalm(input_prompt)    
    
# print( "/n output here ::" , df['Gemini_ultra_model_output'][i])
# df = df.assign(Gemini_ultra_model_output=generate(df.combine_prompt))
# df['combine_prompt'].head(3)

# df['Gemini_ultra_model_output'].head(3)
# Out:
# iteration # 0
# Response from Model:  This context does not mention anything about Harry Potter or magical creatures, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not contain any information about Harry Potter or any magical creatures.
# Response from Model:  The provided information does not contain the answer to the question.
# iteration # 1
# Response from Model:  The provided text does not contain any information about the name of the school newspaper at Hogwarts.
# Response from Model:  This information is not available from the context provided.
# Response from Model:  The provided text does not contain any information about the school newspaper at Hogwarts.
# iteration # 2
# Response from Model:  The provided text does not contain any information about the magical map of Hogwarts.
# Response from Model:  The provided text does not mention anything about a magical map of Hogwarts, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the magical map of Hogwarts, so I cannot answer this question.
# iteration # 3
# Response from Model:  The provided text does not mention Luna Lovegood or Hogwarts houses, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Luna Lovegood or the Hogwarts houses. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Luna Lovegood. Therefore, I cannot answer the question.
# iteration # 4
# Response from Model:  The provided text does not contain any information about Harry Potter or Gringott's Bank.
# Response from Model:  The provided text does not contain any information about Harry Potter or magical creatures guarding Gringott's Bank.
# Response from Model:  The provided text does not mention anything about Harry Potter or Gringotts Bank, so I cannot answer this question.
# iteration # 5
# Response from Model:  This context does not mention anything about the ingredients used in the Polyjuice potion, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Polyjuice potion or its ingredients. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the ingredients used in Polyjuice potion.
# iteration # 6
# Response from Model:  The provided text does not contain any information about Harry Potter or the Sorcerer's Stone, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Sorcerer's Stone, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter, so I cannot answer this question.
# iteration # 7
# Response from Model:  The provided text does not mention Harry Potter or Quidditch, so I cannot answer the question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Quidditch.
# Response from Model:  The provided text does not mention Harry Potter or Quidditch, so I cannot answer this question.
# iteration # 8
# Response from Model:  The provided text does not mention Hermione or Dumbledore's Army, so I cannot answer this question from the provided text.
# Response from Model:  The provided text does not mention Hermione or Dumbledore's Army, so I cannot answer this question from the given context.
# Response from Model:  The text provided does not mention anything about Harry Potter, Hermione, or Dumbledore's Army, so I cannot answer this question from the provided context.
# iteration # 9
# Response from Model:  The provided text does not contain any information about Hermione's cat's name.
# Response from Model:  The text you provided does not mention Hermione's cat.
# Response from Model:  The provided text does not mention anything about Harry Potter or Hermione's cat. So I cannot provide an answer to this question from the given context.
# iteration # 10
# Response from Model:  The provided text does not mention Harry Potter or Diagon Alley, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter or Diagon Alley, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about the Harry Potter series or Diagon Alley.
# iteration # 11
# Response from Model:  The provided text does not mention anything about Harry Potter, Fred, George, or eavesdropping tools. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter, Fred, George, or any eavesdropping tool, so I cannot answer the question.
# Response from Model:  The provided text does not mention any eavesdropping tool invented by Fred and George in Harry Potter and the Order of the Phoenix.
# iteration # 12
# Response from Model:  The provided text does not mention Harry Potter or any information related to the Slytherin ghost.
# Response from Model:  The provided text does not mention anything about the Slytherin ghost, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Slytherin ghost.
# iteration # 13
# Response from Model:  There is no mention of Harry Potter or his children in the text provided. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any of his children, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or his children's names.
# iteration # 14
# Response from Model:  The provided text does not contain any information about bezoars or where to find them.
# Response from Model:  The provided text does not contain any information about bezoars.
# Response from Model:  The provided text does not mention anything about bezoars. So I cannot answer this question from the provided context.
# iteration # 15
# Response from Model:  The provided text does not mention Harry Potter or any of the characters from the Harry Potter series. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters from the Harry Potter series. So I cannot answer this question.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided context.
# iteration # 16
# Response from Model:  The provided text does not mention Harry Potter or a zoo, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter, so I am unable to answer the question.
# Response from Model:  The provided text does not mention Harry Potter or any information related to the Harry Potter series. Therefore, I cannot answer the question.
# iteration # 17
# Response from Model:  The provided text does not mention anything about Harry Potter, the Dursleys, or Dobby. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or the Dursleys, so I cannot answer this question.
# Response from Model:  This information cannot be found in the text provided.
# iteration # 18
# Response from Model:  The provided text does not include any information about Harry Potter or Mrs. Weasley, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or the boggart.
# Response from Model:  The provided text does not mention anything about Harry Potter or the boggart, so I cannot answer this question.
# iteration # 19
# Response from Model:  The text provided does not mention Harry Potter or any of the characters or events from the Harry Potter series. Therefore, I cannot answer the question.
# Response from Model:  The provided text does not mention Harry Potter or any characters or events from the Harry Potter series. It is about the book "Winnie-the-Pooh" by A.A. Milne. So I cannot answer your question.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided information.
# iteration # 20
# Response from Model:  This context does not mention anything about Hermione Granger or extra lessons, so I cannot answer this question from the provided context.
# Response from Model:  The text provided does not contain any information about Hermione or Harry Potter.
# Response from Model:  The provided text does not mention Hermione nor her taking extra lessons, so I cannot answer this question.
# iteration # 21
# Response from Model:  The provided text does not mention anything about Harry Potter or the Chamber of Secrets, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Chamber of Secrets, so I cannot answer the question.
# Response from Model:  The provided text does not mention Harry Potter or the Chamber of Secrets, so I cannot answer the question.
# iteration # 22
# Response from Model:  The provided text does not mention Harry Potter or any of the characters from the Harry Potter series. It is about Winnie-the-Pooh, a character from a different children's book series.
# Response from Model:  The provided text does not mention Ron or any insects that he may be afraid of, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Ron's fear of insects, so I cannot answer this question from the provided context.
# iteration # 23
# Response from Model:  The provided text does not mention Hagrid or his half-brother, so I cannot answer this question.
# Response from Model:  The provided text does not mention Hagrid or his half-brother, so I cannot answer this question.
# Response from Model:  This context does not mention Hagrid or his half-brother, so I cannot answer this question from the provided context.
# iteration # 24
# Response from Model:  The provided text does not mention Harry Potter or any of its characters, including Hermione. So I cannot answer this question.
# Response from Model:  The provided text does not mention Hermione's patronus, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Hermione's patronus.
# iteration # 25
# Response from Model:  This context does not mention anything about the name of the Weasley twins' magic joke shop, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the name of the Weasley twins' magic joke shop, so I cannot answer this question.
# Response from Model:  The provided text does not mention the name of the Weasley twins' magic joke shop, so I cannot answer this question from the provided text.
# iteration # 26
# Response from Model:  The provided text does not contain any information about Harry Potter or his birthplace. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any information related to him. Therefore, I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter.
# iteration # 27
# Response from Model:  The provided text does not mention Professor McGonagall or any information about her animagus form.
# Response from Model:  The provided text does not mention Professor McGonagall or her animagus form.
# Response from Model:  The provided text does not contain any information about Professor McGonagall's animagus.
# iteration # 28
# Response from Model:  The provided text does not mention anything about Harry Potter or the Gryffindor ghost, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter or the Gryffindor ghost, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention anything about Harry Potter or the Gryffindor ghost, so I cannot answer this question.
# iteration # 29
# Response from Model:  The provided text does not mention Harry Potter or any information about Fluffy.
# Response from Model:  The provided text does not mention Fluffy, so I cannot answer this question.
# Response from Model:  There is no mention of Fluffy in the provided text.
# iteration # 30
# Response from Model:  There is no information about Harry Potter or his godfather in the provided text.
# Response from Model:  The provided text does not mention anything about Harry Potter or his godfather, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or his godfather, so I cannot answer this question.
# iteration # 31
# Response from Model:  The provided text does not contain any information about Voldemort or his real name.
# Response from Model:  The provided text does not mention anything about Voldemort or his real name.
# Response from Model:  The provided text does not mention anything about Voldemort or his real name, so I cannot answer this question from the provided context.
# iteration # 32
# Response from Model:  The context you provided does not mention anything about the British term for a nonmagical person.
# Response from Model:  The provided text does not contain any information about the British term for a nonmagical person.
# Response from Model:  The provided text does not contain any information about the British term for a nonmagical person.
# iteration # 33
# Response from Model:  The provided text does not mention anything about Harry Potter, Ron Weasley, Draco Malfoy, or Ginny Weasley, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter or any of the characters you listed.
# Response from Model:  The provided text does not mention Harry Potter, Ron Weasley, Draco Malfoy, or Ginny Weasley or anything related to the topic of who is NOT in Gryffindor. So I cannot answer this question.
# iteration # 34
# Response from Model:  The provided text does not mention Harry Potter or any of the characters from the Harry Potter series. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or his middle name.
# Response from Model:  The provided text does not contain any information about Harry Potter.
# iteration # 35
# Response from Model:  The provided text does not mention anything about Hogwarts students or O.W.L.s, so I cannot answer this question.
# Response from Model:  The provided text does not mention Hogwarts students or O.W.L.s, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Hogwarts students or O.W.L.s, so I cannot answer this question from the provided context.
# iteration # 36
# Response from Model:  The provided information does not contain any details about Harry Potter or his Firebolt.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Harry Potter or a Firebolt. So I cannot answer this question.
# iteration # 37
# Response from Model:  The provided text does not contain any information about the Harry Potter series, so I cannot answer the question.
# Response from Model:  The text provided does not mention Harry Potter.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Battle of Hogwarts, so I cannot answer this question.
# iteration # 38
# Response from Model:  The provided text does not mention Xenophilius Lovegood or the magazine he publishes.
# Response from Model:  The information you provided does not mention Xenophilius Lovegood or the name of the magazine he publishes.
# Response from Model:  The provided text does not mention Xenophilius Lovegood or the magazine he publishes.
# iteration # 39
# Response from Model:  The text you provided does not contain any information about the Harry Potter series, so I am unable to answer your question.
# Response from Model:  The provided text does not mention anything about the Harry Potter series or incantations for levitation.
# Response from Model:  The provided text does not mention any incantations or spells related to levitation. So I cannot answer this question.
# iteration # 40
# Response from Model:  The provided text does not contain any information about Harry Potter or Hogwarts. So I cannot answer this question.
# Response from Model:  There is no mention of Harry Potter or any information about him in the provided text.
# Response from Model:  This context does not mention anything about Harry Potter, Hogwarts, or expulsion, so I cannot answer this question from the provided context.
# iteration # 41
# Response from Model:  The provided text does not mention the Black family home's address.
# Response from Model:  The provided text does not specify the address of the Black family home.
# Response from Model:  The provided text does not contain any information about the Black family home address.
# iteration # 42
# Response from Model:  The provided text does not contain any information about Harry Potter, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter, so I cannot answer this question from the provided context.
# Response from Model:  This text does not contain any information about Harry Potter.
# iteration # 43
# Response from Model:  The provided text does not mention the Weasley children or their birth order, so I cannot answer this question.
# Response from Model:  This context does not mention anything about the Weasley children, so I cannot answer this question from the provided context.
# Response from Model:  The text provided does not contain any information about the birth order of the Weasley children, so I cannot answer this question from the provided text.
# iteration # 44
# Response from Model:  The provided text does not mention Harry Potter or any of the characters or events from the Harry Potter series, so I cannot answer the question.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters or events from the Harry Potter series.
# Response from Model:  The provided text does not mention Harry Potter or his father's Invisibility Cloak, so I cannot answer this question.
# iteration # 45
# Response from Model:  The provided text does not mention the animal symbol of Ravenclaw.
# Response from Model:  The provided text does not contain information about the animal symbol of Ravenclaw.
# Response from Model:  The provided text does not contain any information about the animal symbol of Ravenclaw.
# iteration # 46
# Response from Model:  The provided text does not mention Hagrid or his boarhound dog.
# Response from Model:  The provided text does not mention Hagrid or his boarhound dog, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or Hagrid's boarhound dog.
# iteration # 47
# Response from Model:  The provided text does not contain any information about a pet dragon.
# Response from Model:  There is no information provided about Harry Potter or his pet dragon in the given text. The text is about Winnie-the-Pooh, a character from a different children's book series.
# Response from Model:  The provided text does not mention anything about Harry Potter, dragons, or pets. So I cannot provide an answer to your question.
# iteration # 48
# Response from Model:  The provided text does not contain any information about Harry Potter, Lily Potter, James Potter, Moony, Professor Snape, Padfoot, or Wormtail, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters you listed. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters you listed, so I cannot answer this question.
# iteration # 49
# Response from Model:  The provided text does not mention the Weasley family or their home.
# Response from Model:  The provided text does not mention the Weasley family home.
# Response from Model:  The provided text does not contain any information about the Weasley family home, so I cannot answer this question from the provided context.
# iteration # 50
# Response from Model:  The provided text does not mention any potion that gives good luck to those who drink it.
# Response from Model:  The provided text does not mention any potion that gives good luck to those who drink it.
# Response from Model:  The text provided does not contain any information about potions that give good luck to those who drink it.
# iteration # 51
# Response from Model:  The provided text does not contain any information about the maiden name of Lily Potter and Petunia Dursley.
# Response from Model:  The provided text does not mention the maiden name of Lily Potter or Petunia Dursley.
# Response from Model:  The provided text does not mention the maiden name of sisters Lily Potter and Petunia Dursley.
# iteration # 52
# Response from Model:  The provided text does not mention Harry Potter or any of the characters you listed, so I cannot answer this question.
# Response from Model:  The context does not mention Harry Potter characters or their houses, so the question cannot be answered.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters you listed, so I cannot answer this question.
# iteration # 53
# Response from Model:  The text provided does not mention anything about James and Lily Potter. So I cannot answer this question from the provided context.
# Response from Model:  The context provided does not contain any information about James and Lily Potter, so I cannot answer this question.
# Response from Model:  The provided Winnie-the-Pooh text does not contain any information about James and Lily Potter's death.
# iteration # 54
# Response from Model:  The provided text does not mention Professor McGonagall or the classes she teaches. So I cannot answer this question from the provided information.
# Response from Model:  This context does not mention anything about Harry Potter or Professor McGonagall, so I cannot answer this question from the provided context.
# Response from Model:  This context does not mention anything about Harry Potter, Professor McGonagall, or Hogwarts, so I cannot answer this question from the provided context.
# iteration # 55
# Response from Model:  The context provided is about Winnie the Pooh, and does not contain any information about the Harry Potter series or Bill Weasley. Therefore, I am unable to answer your question.
# Response from Model:  The context provided does not mention Harry Potter or any of the characters you mentioned. So I cannot answer this question.
# Response from Model:  The provided text does not mention Bill Weasley or his marriage.
# iteration # 56
# Response from Model:  The provided text does not mention Harry Potter or wands, so I cannot answer this question from the provided information.
# Response from Model:  This context does not mention anything about Harry Potter or wands, so I cannot answer this question from the provided information.
# Response from Model:  This context does not mention anything about Harry Potter or his wand, so I cannot answer this question from the provided context.
# iteration # 57
# Response from Model:  This question cannot be answered. The provided text does not mention anything about Harry Potter or Horcruxes.
# Response from Model:  The provided information does not mention anything about Harry Potter or Horcruxes. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter, Horcruxes, or Voldemort. So I cannot answer this question from the provided context.
# iteration # 58
# Response from Model:  The provided text does not mention anything about "A History of Magic" or its author, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the author of A History of Magic.
# Response from Model:  The provided text does not contain any information about the book A History of Magic or its author.
# iteration # 59
# Response from Model:  The context does not have information about Harry Potter.
# Response from Model:  The provided text does not contain any information about Harry Potter. Therefore, I cannot answer the question.
# Response from Model:  The text provided does not mention anything about Harry Potter, Dobby, or the Harry Potter book series. So I cannot answer your question.
# iteration # 60
# Response from Model:  The provided text does not mention Justin Finch-Fletchley or any Hogwarts houses, so I cannot answer this question.
# Response from Model:  The provided text does not mention Justin Finch-Fletchley or any Hogwarts houses, so I cannot answer this question.
# Response from Model:  The provided text does not mention Justin Finch-Fletchley or any Hogwarts houses.
# iteration # 61
# Response from Model:  The provided text does not contain any information about Harry Potter or Hagrid, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter or Hagrid, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Hagrid, so I cannot answer this question.
# iteration # 62
# Response from Model:  The provided text does not mention Quidditch or the number of players on a team.
# Response from Model:  The provided text does not contain any information about Quidditch or the number of players on a Quidditch team.
# Response from Model:  This context does not mention anything about Quidditch or the number of players on a Quidditch team, so I cannot answer this question from the provided context.
# iteration # 63
# Response from Model:  The provided text does not contain any information about the Deathly Hallows or the title of the children's book in which the story can be found.
# Response from Model:  The text you have provided does not mention the Deathly Hallows or Harry Potter. So I cannot answer this question.
# Response from Model:  The context provided does not mention anything about Harry Potter or the Deathly Hallows, so I cannot answer this question.
# iteration # 64
# Response from Model:  There is no mention of the Chamber of Secrets in the provided text.
# Response from Model:  The provided text does not mention the Chamber of Secrets or its entrance, so I cannot answer this question from the provided context.
# Response from Model:  The text provided does not mention the Chamber of Secrets or its entrance.
# iteration # 65
# Response from Model:  The provided text does not mention anything about Harry Potter or Hogwarts, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or Hogwarts, it is about Winnie the Pooh. So I cannot answer this question.
# Response from Model:  The provided text does not mention anything about the teleportation magic that sixth-years learn at Hogwarts.
# iteration # 66
# Response from Model:  The provided text does not contain any information about Aragog or any magical creatures from the Harry Potter series.
# Response from Model:  The provided text does not contain any information about Aragog or any other magical creatures from the Harry Potter series.
# Response from Model:  The provided text does not mention Aragog or any magical creatures.
# iteration # 67
# Response from Model:  The provided text does not mention Ron Weasley or Quidditch teams, so I cannot answer this question.
# Response from Model:  The provided text does not mention Ron's favorite Quidditch team.
# Response from Model:  The provided text does not mention Ron's favorite Quidditch team, so I cannot answer this question.
# iteration # 68
# Response from Model:  The provided text does not mention Neville's birthday.
# Response from Model:  The provided text does not mention Neville's birthday, so I cannot answer this question.
# Response from Model:  The provided text does not mention Neville or his birthday.
# iteration # 69
# Response from Model:  The provided text does not contain any information about James Potter or his Marauder nickname.
# Response from Model:  The provided text does not contain any information about James Potter or his Marauder nickname.
# Response from Model:  The provided text does not mention James Potter or his Marauder nickname, so I cannot answer this question.
# iteration # 70
# Response from Model:  The context provided does not contain any information about the Grey Lady or Rowena Ravenclaw. Therefore, I cannot answer this question.
# Response from Model:  The text provided does not contain any information about Harry Potter, so I cannot answer your question.
# Response from Model:  The provided text does not contain any information about the Grey Lady or Rowena Ravenclaw.
# iteration # 71
# Response from Model:  The provided text does not mention Charlie Weasley or his career after graduation.
# Response from Model:  The information provided does not mention Charlie Weasley or what he does for a living after graduation.
# Response from Model:  The provided text does not mention Charlie Weasley or what he does for a living after graduation.
# iteration # 72
# Response from Model:  The provided text does not contain any information about Harry Potter or Buckbeak.
# Response from Model:  The provided text does not mention Buckbeak or his execution.
# Response from Model:  The provided text does not mention Harry Potter or Buckbeak.
# iteration # 73
# Response from Model:  The provided text does not contain any information about Dean Thomas or his favorite sport.
# Response from Model:  The provided text does not contain any information about Dean Thomas or his favorite sport.
# Response from Model:  The provided text does not mention Dean Thomas or his favorite sport.
# iteration # 74
# Response from Model:  The provided text does not contain any information about Harry Potter or the Triwizard Tournament, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or the Triwizard Tournament, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Triwizard Tournament. So I cannot answer this question.
# iteration # 75
# Response from Model:  This context does not mention anything about Voldemort's mother's name, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Voldemort's mother's name.
# Response from Model:  The provided text does not mention Voldemort's mother's name, so I cannot answer this question.
# iteration # 76
# Response from Model:  The provided text does not contain any information about Harry Potter or Quidditch.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided context.
# Response from Model:  This context does not mention anything about the Gryffindor Quidditch team or Harry Potter, so I cannot answer this question.
# iteration # 77
# Response from Model:  The provided text does not contain any information about Gringotts or break-ins.
# Response from Model:  The provided information does not mention Gringotts or any break-ins, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Gringotts or anyone breaking into it, so I cannot answer this question.
# iteration # 78
# Response from Model:  The provided text does not mention Bellatrix or Tonks, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or the characters you mentioned. It is about Winnie-the-Pooh. Therefore, I cannot answer your question.
# Response from Model:  This context does not mention anything about Bellatrix or Tonks, so I cannot answer this question from the provided context.
# iteration # 79
# Response from Model:  The provided text does not contain any information about Winky the house-elf or her family.
# Response from Model:  The provided text does not mention Winky the house-elf or any information about her family.
# Response from Model:  The provided text does not mention Winky the house-elf or any other characters from the Harry Potter series.
# iteration # 80
# Response from Model:  The provided text does not contain any information about Nearly Headless Nick.
# Response from Model:  The provided text does not mention Nearly Headless Nick or his full name, so I cannot answer this question.
# Response from Model:  The provided text does not mention Nearly Headless Nick or provide any information related to Harry Potter.
# iteration # 81
# Response from Model:  The information you have provided does not mention anything about the Sorcerer's Stone or Nicolas Flamel. Therefore, I am unable to provide an answer to this question.
# Response from Model:  The provided text does not mention the Sorcerer's Stone or Nicolas Flamel, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the Sorcerer's Stone or Nicolas Flamel.
# iteration # 82
# Response from Model:  The provided text does not mention monkshood, wolfsbane, or any other plants.
# Response from Model:  The provided information does not include any mention of Monkshood or wolfsbane, therefore I cannot answer this question from the provided text.
# Response from Model:  This context does not mention anything about monkshood, wolfsbane, or any other plants, so I cannot answer this question from the provided context.
# iteration # 83
# Response from Model:  The text you provided does not contain any information about Harry Potter or Hogwarts.
# Response from Model:  This context does not mention anything about Hogwarts or its staircases, so I cannot answer this question.
# Response from Model:  The provided text does not mention the number of staircases in Hogwarts.
# iteration # 84
# Response from Model:  The provided text does not contain any information about Harry Potter or the Hall of Prophecy.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Hall of Prophecy.
# Response from Model:  The provided text does not mention anything about Harry Potter, Voldemort, or the Hall of Prophecy, so I cannot answer this question.
# iteration # 85
# Response from Model:  The provided text does not contain any information about Quidditch fouls.
# Response from Model:  The provided text does not contain any information about Quidditch fouls.
# Response from Model:  The provided text does not contain any information about Quidditch fouls.
# iteration # 86
# Response from Model:  The provided text does not mention Albus Dumbledore or any scar on his left knee. So I cannot answer this question.
# Response from Model:  This context does not mention anything about Dumbledore's scar above his left knee, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention anything about Dumbledore or a scar on his left knee. Therefore, I cannot provide an answer to this question from the provided information.
# iteration # 87
# Response from Model:  The provided text does not mention Harry Potter or the Weasleys' crabapple tree, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry's 17th birthday or Hermione turning the leaves of the Weasleys' crabapple tree.
# Response from Model:  The provided text does not contain any information about Harry Potter or his birthday. So I cannot answer this question.
# iteration # 88
# Response from Model:  The provided text does not mention Cedric Diggory or Harry Potter, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or Cedric Diggory, so I cannot answer this question.
# Response from Model:  There is no evidence of Cedric Diggory mentioned in this provided text.
# iteration # 89
# Response from Model:  The provided text does not contain any information about Harry Potter and the Prisoner of Azkaban, or about Hermione, Harry, and Ron finding Crookshanks.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Prisoner of Azkaban, or about Hermione, Harry, Ron, or Crookshanks. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any of the characters from the series, so I cannot answer this question.
# iteration # 90
# Response from Model:  The provided text does not contain any information about the max speed of a Firebolt broomstick.
# Response from Model:  The provided text does not mention anything about the max speed of a Firebolt broomstick.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Firebolt broomstick.
# iteration # 91
# Response from Model:  The provided text does not contain any information about the Quidditch World Cup, Ireland's team, or any chasers named Mullet, Troy, or Moran.
# Response from Model:  The provided text does not mention the Quidditch World Cup or the Irish team's chasers. So I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Quidditch, Ireland's team, or the Quidditch World Cup, so I cannot answer this question.
# iteration # 92
# Response from Model:  The provided text does not contain any information about Helga Hufflepuff's cup or Hepzibah Smith.
# Response from Model:  The provided text does not contain any information about Harry Potter or Voldemort stealing Helga Hufflepuff's cup from an old woman named Hepzibah Smith.
# Response from Model:  The provided information does not specify the name of Hepzibah Smith's house-elf, so I cannot answer this question from the given context.
# iteration # 93
# Response from Model:  The information you are looking for cannot be found in the text provided.
# Response from Model:  The provided text does not mention Ginny Weasley or her pet Pygmy Puff, so I cannot answer this question from the given context.
# Response from Model:  The text provided does not contain any information about Harry Potter or Ginny Weasley.
# iteration # 94
# Response from Model:  There is no mention of the Grey Lady in the provided text.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Grey Lady.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Grey Lady.
# iteration # 95
# Response from Model:  The text provided does not contain any information about Harry Potter or Quidditch.
# Response from Model:  The provided text does not contain any information about the Quidditch team on the sock Mrs. Weasley tries to give to Harry.
# Response from Model:  This context does not mention anything about Harry Potter or Quidditch, so I cannot answer this question from the provided information.
# iteration # 96
# Response from Model:  The provided text does not contain any information about Teddy Lupin or the color of his hair.
# Response from Model:  The provided text does not contain any information about Teddy Lupin or the color of his hair.
# Response from Model:  The provided text does not contain any information about Teddy Lupin's hair color when he is born.
# iteration # 97
# Response from Model:  The provided text does not contain any information about Hermione Granger or scents that attract her.
# Response from Model:  The provided text does not contain any information about Hermione Granger's scent preferences.
# Response from Model:  The provided text does not mention Hermione Granger or any scents that attract her.
# iteration # 98
# Response from Model:  The provided text does not contain any information about Gilderoy Lockhart or Witch Weekly's Most Charming Smile Award. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Gilderoy Lockhart or Witch Weekly's Most Charming Smile Award.
# Response from Model:  The provided text does not contain any information about Gilderoy Lockhart or Witch Weekly's Most Charming Smile Award. So I cannot answer this question.
# iteration # 99
# Response from Model:  The provided text does not contain any information about Draco Malfoy's wand.
# Response from Model:  The provided text does not mention Draco Malfoy or his wand, so I cannot answer this question.
# Response from Model:  The provided text does not mention Draco Malfoy or his wand, so I cannot answer this question.
# iteration # 100
# Response from Model:  The provided text does not mention Voldemort or an orphanage, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention anything about the matron of the orphanage where Voldemort grows up. So I cannot answer this question.
# Response from Model:  The provided text does not mention Voldemort's orphanage or its matron.
# Response from Model:  The text provided does not contain any information about Lord Voldemort's orphanage.
# Response from Model:  The provided text does not contain any information about Lord Voldemort or the orphanage where he grew up.
# Response from Model:  The provided text does not contain information about Lord Voldemort's orphanage.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Prisoner of Azkaban or the replacement of the Fat Lady's portrait, so I cannot answer this question from the provided context.
# Response from Model:  The information provided does not mention Harry Potter, so I cannot answer this question.
# Response from Model:  The provided information does not contain any information about Harry Potter and the Prisoner of Azkaban.
# Response from Model:  This text does not contain information about Professor Kettleburn. So I cannot answer this question.
# Response from Model:  The provided text does not mention Professor Kettleburn or his retirement plans, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Professor Kettleburn or his retirement plans.
# Response from Model:  The provided text does not contain any information about Lockhart's favorite color.
# Response from Model:  The provided text does not mention anything about Lockhart or his favorite color, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Lockhart or his favorite color, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or any characters or events from the Harry Potter series.
# Response from Model:  The provided text is about Winnie-the-Pooh, not Harry Potter. So I cannot provide an answer to your question.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Chamber of Secrets. So I am unable to answer your question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Hermione.
# Response from Model:  The provided text does not mention Hermione or Jupiter's largest moon.
# Response from Model:  The context provided does not mention Harry Potter, Hermione, or Jupiter's largest moon.
# Response from Model:  The provided text does not mention Harry Potter or the spell Accio.
# Response from Model:  The provided information does not contain any details about Harry Potter or the spell Accio, so I cannot answer this question.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Lily Potter's birthday, so I cannot answer this question from the provided text.
# Response from Model:  The provided text does not mention Lily Potter or her birthday, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Lily Potter's birthday.
# Response from Model:  This context does not mention anything about Snape's birthday, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention anything about Snape's birthday, so I cannot answer this question.
# Response from Model:  The provided text does not mention Severus Snape or his birthday, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter or Hermione, so I cannot answer the question.
# Response from Model:  The provided text does not mention Hermione or Cheering Charms, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Hermione. It is about the children's book Winnie-the-Pooh.
# Response from Model:  This text does not mention anything about Harry Potter and the Half-Blood Prince, so I can't answer this question.
# Response from Model:  The provided text does not provide any information about Harry Potter and the Half-Blood Prince, the Weasleys' magical clock, or Harry arriving at the Burrow. So I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Half-Blood Prince, or the Weasleys' magical clock.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or any of its characters. Therefore, I cannot answer the question.
# Response from Model:  The provided text does not mention Harry Potter or any of its characters, including Ginny and Ron. So I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or his daughter, Lily. So I cannot answer this question.
# Response from Model:  This text does not mention anything about Harry Potter or his daughter, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Harry Potter or his daughter, Lily. So I cannot answer this question.
# Response from Model:  This context does not mention anything about Harry Potter, so I cannot answer this question.
# Response from Model:  The information you provided does not mention anything about the Harry Potter series or Hogwarts. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Prisoner of Azkaban or the secret passage from Hogwarts to Honeydukes.
# Response from Model:  The provided text does not mention Ron Weasley's middle name, so I cannot answer this question from the provided context.
# Response from Model:  The context does not mention Ron's middle name.
# Response from Model:  The provided text does not mention Ron or his middle name.
# Response from Model:  The provided text does not mention Harry Potter or the Peverell brothers, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the Peverell brothers, so I cannot answer this question.
# Response from Model:  The provided text does not mention the Peverell brothers or Harry Potter.
# Response from Model:  The provided text does not mention anything about Harry Potter or Hogsmeade, so I cannot answer this question.
# ...
# Response from Model:  The provided text does not contain any information about Harry Potter or the Weasleys, so I cannot answer this question.
# Response from Model:  The provided text does not mention the Harry Potter series or any spells, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the Harry Potter series or spells like Lumos, so I cannot answer this question.
# Response from Model:  The provided text does not contain information about the Harry Potter universe or spells.
# Response from Model:  The provided text does not specify the color of Crookshanks's fur, so I cannot answer this question from the provided context.
# Response from Model:  This context does not mention anything about Crookshanks or their fur color, so I cannot answer this question from the provided text.
# Response from Model:  The provided text does not mention Crookshanks or the color of his fur.
# Response from Model:  The provided text does not mention Nicolas Flamel or his wife.
# Response from Model:  The provided text does not mention Nicolas Flamel or his wife.
# Response from Model:  The provided text does not mention Nicolas Flamel or his wife, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Quidditch or the balls used in the sport.
# Response from Model:  The provided text does not mention Quidditch or any balls used in the sport. So I cannot answer this question from the provided text.
# Response from Model:  The provided text does not mention Quidditch or any of its components, including the size of any balls used in the game. Therefore, I cannot answer this question.
# Response from Model:  The provided text does not mention Dumbledore's favorite flavor of jam.
# Response from Model:  The provided text does not mention Dumbledore or his favorite flavor of jam, so I cannot answer this question.
# Response from Model:  The provided text does not specify Dumbledore’s favorite flavor of jam.
# Response from Model:  The provided text does not contain any information about Professor Trelawney or Harry Potter.
# Response from Model:  The provided text does not contain any information about Professor Trelawney.
# Response from Model:  The provided text does not mention Professor Trelawney or her first name.
# Response from Model:  The provided text does not contain information about the currency of the Harry Potter universe, therefore I cannot answer that question from the provided context.
# Response from Model:  The text provided does not mention the number of Knuts in a Sickle, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about the Harry Potter series or its currency system, so I cannot answer this question from the given context.
# Response from Model:  The provided text does not mention the Department of Mysteries or its employees, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the Department of Mysteries or its employees, so I cannot answer this question.
# Response from Model:  This context does not mention anything about the employees of the Department of Mysteries, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Bill and Fleur's eldest child.
# Response from Model:  The provided text does not mention Bill and Fleur or their children. So I cannot answer this question.
# Response from Model:  The information provided does not contain any information about Harry Potter characters.
# Response from Model:  This context does not mention anything about Dumbledore's middle name, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Dumbledore or provide any information about him, so I cannot answer this question.
# Response from Model:  The provided text does not mention Dumbledore or his middle name.
# Response from Model:  This context does not mention anything about the Triwizard Tournament or Christmas events, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the Christmas event held to celebrate the Triwizard Tournament.
# Response from Model:  The provided text does not contain any information about the Christmas event held to celebrate the Triwizard Tournament.
# Response from Model:  The provided text does not mention Hannah Abbott or the sorting of students into houses.
# Response from Model:  The provided text does not mention Hannah Abbott or any of the Hogwarts houses, so I cannot answer this question from the given information.
# Response from Model:  The provided text does not mention Hannah Abbott or the sorting of students into houses at Hogwarts, so I cannot answer this question.
# Response from Model:  The provided context does not include any information about Harry Potter and the Prisoner of Azkaban, so I am unable to answer the question.
# Response from Model:  This text does not contain any information about Harry Potter.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Prisoner of Azkaban, or about Harry giving Stan a name when he gets on the Knight Bus. Therefore, I cannot answer this question from the provided text.
# Response from Model:  The provided text does not contain any information about the Quidditch World Cup or the Bulgarian mascot.
# Response from Model:  This context does not mention anything about the Quidditch World Cup or the Bulgarians, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not contain any information about the Quidditch World Cup or the Bulgarian mascot.
# Response from Model:  The provided text does not contain any information about S.P.E.W.
# Response from Model:  This context does not mention anything about S.P.E.W., so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about S.P.E.W.
# Response from Model:  The provided text does not contain any information about Neville's parents, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Neville's parents.
# Response from Model:  The text provided does not contain any information about Neville's parents.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Goblet of Fire, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Goblet of Fire, or the answer to the sphinx's riddle.
# Response from Model:  The provided text does not contain information about Harry Potter and the Goblet of Fire, or any information about the third task or the sphinx's riddle.
# Response from Model:  The text provided does not contain any information about Harry Potter or Rita Skeeter.
# Response from Model:  There is no information provided about Rita Skeeter listening to private conversations at Hogwarts all year in the provided text.
# Response from Model:  The provided information does not mention Rita Skeeter's methods for eavesdropping on private conversations at Hogwarts.
# Response from Model:  The provided text does not contain any information about Aunt Petunia or a Howler. So I cannot answer this question.
# Response from Model:  The text provided does not mention a Howler received by Aunt Petunia.
# Response from Model:  The provided text does not contain any information about a Howler received by Aunt Petunia.
# Response from Model:  The provided text does not mention Harry Potter or the Room of Requirement, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or the Room of Requirement, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or the Room of Requirement, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter or the Goblet of Fire, so I am unable to answer this question.
# Response from Model:  The provided text does not mention Harry Potter or any characters or events from the Harry Potter series.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Goblet of Fire or the Muggle whom Voldemort kills inside the Riddle House.
# Response from Model:  The provided text does not contain any information about Harry, Ron, Hermione, Dumbledore's Army, or their communication methods. So I cannot answer this question.
# Response from Model:  The text you provided does not include any information about Harry Potter, Ron, Hermione, Dumbledore's Army, or any form of communication.
# Response from Model:  The provided text does not contain any information about Harry, Ron, Hermione, or Dumbledore's Army. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or St. Mungo's.
# Response from Model:  The provided text does not mention Neville or St. Mungo's. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Neville Longbottom or St. Mungo's, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter or centaurs replacing professors.
# Response from Model:  The provided text does not contain information about the name of the centaur that replaces Trelawney as the professor of Divination.
# Response from Model:  The provided text does not mention the name of the centaur that replaces Trelawney as the professor of Divination.
# Response from Model:  The text provided does not contain any information about Harry Potter, the Order of the Phoenix, Grimmauld Place, or Sirius.
# Response from Model:  The provided text does not contain any information about the Order of the Phoenix or Sirius. So I cannot answer the question.
# Response from Model:  The provided information does not mention anything about Harry Potter or the Order of the Phoenix moving out of 12 Grimmauld Place. So I cannot answer this question.
# Response from Model:  This context does not mention anything about Harry Potter and the Half-Blood Prince, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Harry Potter or any of its characters, including Ginny or Fleur. So I cannot answer the question.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Half-Blood Prince or any nicknames used in the book.
# Response from Model:  The provided text does not mention Ginny or the Slug Club meeting on the Hogwarts Express, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter, Ginny, or the Slug Club.
# Response from Model:  The provided text does not mention Ginny or the Slug Club meeting on the Hogwarts Express, so I cannot answer the question.
# Response from Model:  The text you provided does not contain any information about Harry Potter, Tom Riddle, or Dumbledore. So I cannot answer the question.
# Response from Model:  The provided text does not contain any information about Harry Potter or Tom Riddle.
# Response from Model:  This context does not mention anything about Harry Potter, Tom Riddle, or Dumbledore, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention anything about Harry Potter or Apparition, so I cannot answer this question from the provided context.
# Response from Model:  The text you provided does not mention Harry Potter or the process of Apparition.
# Response from Model:  The provided text does not mention anything about the "three D's" everyone must remember while learning to Apparate.
# Response from Model:  The information you are requesting is not found in the text provided.
# Response from Model:  The context provided does not mention Harry Potter and the Deathly Hallows or any information about Ron's cover story. So I cannot answer this question.
# Response from Model:  The text you have provided does not contain the answer to your question about Ron's cover story for his absence from Hogwarts.
# Response from Model:  The provided text does not contain any information about Harry Potter.
# Response from Model:  The provided text does not mention Harry Potter or any of the events from the Harry Potter books, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter, Bill and Fleur's wedding, or disguises, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or the Ministry of Magic, so I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Harry Potter or the Ministry of Magic, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter or the Ministry of Magic, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about James and Lily Potter's grave or the quote written on it.
# Response from Model:  The provided text does not contain any information about James and Lily's grave or the quote written on it.
# Response from Model:  The provided text does not mention James and Lily Potter's grave or the quote inscribed on it.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Deathly Hallows. Therefore, I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Harry Potter and the Deathly Hallows, so I cannot answer this question.
# Response from Model:  The provided text does not mention Harry Potter and the Deathly Hallows or any information about how the Death Eaters find Harry, Hermione, and Ron in the forest.
# Response from Model:  The context provided does not mention Harry Potter or any characters from the Harry Potter series. It is about Winnie-the-Pooh and his introduction in the book "Winnie-the-Pooh and Some Bees, and the Stories Begin" by A. A. Milne. Therefore, I cannot answer the question about how Peter Pettigrew dies based on the provided information.
# Response from Model:  The provided text does not contain any information about Peter Pettigrew's death.
# Response from Model:  This information is not mentioned in the provided text.
# Response from Model:  The provided text does not mention Ariana Dumbledore or any reason why she would stop using magic.
# Response from Model:  The provided text does not contain any information about Ariana Dumbledore or the reason she stopped using magic.
# Response from Model:  The provided text does not mention Ariana Dumbledore or anything about why she stopped using magic.
# Response from Model:  The provided text does not contain any information about the Harry Potter universe or Ravenclaw's common room.
# Response from Model:  The provided text does not contain information about Ravenclaw's common room or how to get into it.
# Response from Model:  The provided text does not contain any information about Ravenclaw's common room or how to get into it.
# Response from Model:  This text does not mention Harry Potter, Lily, or Snape, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about Harry Potter characters, Lily and Snape, or their first meeting.
# Response from Model:  The provided text does not mention Harry Potter, Lily, or Snape. So I cannot answer this question.

# %%
df_qa.columns
# Out:
# Index(['Question', 'Answer', 'i', 'j', 'k', 'pagewise_texts_v1',
#        'pagewise_texts_v2', 'pagewise_texts_v3', 'splitted_texts_v1',
#        'splitted_texts_v2', 'splitted_texts_v3', 'splitted_texts_chunks_v1',
#        'splitted_texts_chunks_v2', 'splitted_texts_chunks_v3', 'page_id_v1',
#        'page_id_v2', 'page_id_v3', 'combine_prompt_RAG1',
#        'combine_prompt_RAG2', 'combine_prompt_RAG3',
#        'Gemini_ultra_model_output_v1', 'Gemini_ultra_model_output_v2',
#        'Gemini_ultra_model_output_v3', 'palm_bison32k_output_v1',
#        'palm_bison32k_output_v2', 'palm_bison32k_output_v3'],
#       dtype='object')

# %%
# Delete the 'col2' column
df_qa = df_qa.drop('combine_prompt_RAG1', axis=1)
df_qa = df_qa.drop('combine_prompt_RAG2', axis=1)
df_qa = df_qa.drop('combine_prompt_RAG3', axis=1)

output1 = "./harry_potte_qa_model_out.csv"

df_qa.to_csv(output1)

# %%
df_qa.head(1)
# Out:
#                                             Question     Answer  i  j   k  \
# 0  What is the name of the magical creature that ...   Thestral  9  8  19
#
#                                    pagewise_texts_v1  \
# 0  WINNIE-THE-POOH\n“Ah, yes, now I do," I said q...
#
#                                    pagewise_texts_v2  \
# 0  IN WHICH We Are Introduced to\nCHAPTER I\nWinn...
#
#                                    pagewise_texts_v3  \
# 0  WE ARE INTRODUCED\nAB SANDER\nRNIG\nALSO\n"Win...
#
#                                    splitted_texts_v1  \
# 0  WINNIE-THE-POOH\n“Ah, yes, now I do," I said q...
#
#                                    splitted_texts_v2  ...  \
# 0  IN WHICH We Are Introduced to\nCHAPTER I\nWinn...  ...
#
#                             splitted_texts_chunks_v3 page_id_v1 page_id_v2  \
# 0  WE ARE INTRODUCED\nAB SANDER\nRNIG\nALSO\n"Win...          2          1
#
#   page_id_v3                       Gemini_ultra_model_output_v1  \
# 0          3  The provided text does not contain any informa...
#
#                         Gemini_ultra_model_output_v2  \
# 0  The provided text does not contain any informa...
#
#                         Gemini_ultra_model_output_v3  \
# 0  The provided context does not contain any info...
#
#                              palm_bison32k_output_v1  \
# 0   This context does not mention anything about ...
#
#                              palm_bison32k_output_v2  \
# 0   The provided text does not contain any inform...
#
#                              palm_bison32k_output_v3
# 0   The provided information does not contain the...
#
# [1 rows x 23 columns]

# %% [markdown]
# ### Lets now call the Eval function to understand which models were good and which werent so good
