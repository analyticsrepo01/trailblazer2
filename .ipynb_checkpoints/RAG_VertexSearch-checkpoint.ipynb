# %% [markdown]
# ### Configuration and Datasetup

# %%
# !pip install google-cloud-discoveryengine

# %%
# ! pip install --upgrade google-cloud-discoveryengine -q --user

# %%
# TODO(developer): Uncomment these variables before running the sample.
# location = "YOUR_LOCATION" # Values: "global"
# data_store_id = "YOUR_DATA_STORE_ID"

# Must specify either `gcs_uri` or (`bigquery_dataset` and `bigquery_table`)
# Format: `gs://bucket/directory/object.json` or `gs://bucket/directory/*.json`
# gcs_uri = "YOUR_GCS_PATH"
# bigquery_dataset = "YOUR_BIGQUERY_DATASET"
# bigquery_table = "YOUR_BIGQUERY_TABLE"

GCP_PROJECT= PROJECT_ID=project_id='my-project-0004-346516'
LOCATION = location = "global"
# FILE_PATH =file_path =  "Winnie_the_Pooh_3_Pages.pdf"
data_store_id = ""

# Refer to https://cloud.google.com/document-ai/docs/file-types # for supported file types
MIME_TYPE =mime_type = "application/pdf"

gcs_uri = "gs://my-project-0004-346516/matchingengine/books/"

# %%
from typing import Optional

from google.api_core.client_options import ClientOptions
from google.cloud import discoveryengine

from google.cloud import discoveryengine_v1alpha as discoveryengine
from google.api_core.client_options import ClientOptions

# %%
# !gsutil cp -r ./books/* 'gs://my-project-0004-346516/matchingengine/books/'
# Out:
# Copying file://./books/Book1_The_Sorcerers_Stone.pdf [Content-Type=application/pdf]...
# Copying file://./books/Book2_The_Chamber_of_Secrets.pdf [Content-Type=application/pdf]...
# Copying file://./books/Book3_The_Prisoner_of_Azkaban.pdf [Content-Type=application/pdf]...
# Copying file://./books/Book4_The_Goblet_of_Fire.pdf [Content-Type=application/pdf]...
# - [4 files][  8.8 MiB/  8.8 MiB]
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file://./books/Book5_The_Order_of_the_Phoenix.pdf [Content-Type=application/pdf]...
# Copying file://./books/Book6_The_HalfBlood_Prince.pdf [Content-Type=application/pdf]...
# Copying file://./books/Book7_The_Deathly_Hallows.pdf [Content-Type=application/pdf]...
# \ [7 files][ 17.8 MiB/ 17.8 MiB]
# Operation completed over 7 objects/17.8 MiB.

# %%
# !gsutil ls 'gs://my-project-0004-346516/matchingengine/books/'
# Out:
# gs://my-project-0004-346516/matchingengine/books/
# gs://my-project-0004-346516/matchingengine/books/Book1_The_Sorcerers_Stone.pdf
# gs://my-project-0004-346516/matchingengine/books/Book2_The_Chamber_of_Secrets.pdf
# gs://my-project-0004-346516/matchingengine/books/Book3_The_Prisoner_of_Azkaban.pdf
# gs://my-project-0004-346516/matchingengine/books/Book4_The_Goblet_of_Fire.pdf
# gs://my-project-0004-346516/matchingengine/books/Book5_The_Order_of_the_Phoenix.pdf
# gs://my-project-0004-346516/matchingengine/books/Book6_The_HalfBlood_Prince.pdf
# gs://my-project-0004-346516/matchingengine/books/Book7_The_Deathly_Hallows.pdf

# %% [markdown]
# ### Setup Gemini Pro

# %%
# !pip install --upgrade google-cloud-aiplatform
GCP_PROJECT= PROJECT_ID=project_id='my-project-0004-346516'
LOCATION = REGION = 'us-central1'
import os

# import streamlit as st
import vertexai
from vertexai.preview.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)


# @st.cache_resource
def get_model():
    generation_model = TextGenerationModel.from_pretrained("text-bison@002")
    return generation_model


def get_text_generation(prompt="", **parameters):
    generation_model = get_model()
    response = generation_model.predict(prompt=prompt, **parameters)

    return response.text

import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 1,
    "top_k": 40
}

def generate_palm_unicorn_v1(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-unicorn@001")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

def generate_palm_bison32k(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-bison-32k")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part

# input_prompt = """can you give me details of paracetamol"""

def generate(input_prompt):
    model = GenerativeModel("gemini-ultra")
    responses = model.generate_content(
        input_prompt ,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1,
        "top_k": 32
    },
        safety_settings=[],
        stream=True,
    )
    
    all_response  = []
    
    for response in responses:
        # print(response.text, end="")
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))
    

def generate_pro(input_prompt):
    model = GenerativeModel("gemini-pro")
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1
    },stream=True,)
    
    all_response  = []
    
    for response in responses:
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))

# %% [markdown]
# ### Create an empty datastore

# %%
def create_data_store(
    project_id: str, location: str, data_store_name: str, data_store_id: str
):
    # Create a client
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )
    client = discoveryengine.DataStoreServiceClient(client_options=client_options)

    # Initialize request argument(s)
    data_store = discoveryengine.DataStore(
        display_name=data_store_name,
        industry_vertical="GENERIC",
        content_config="CONTENT_REQUIRED",
    )

    request = discoveryengine.CreateDataStoreRequest(
        parent=discoveryengine.DataStoreServiceClient.collection_path(
            project_id, location, "default_collection"
        ),
        data_store=data_store,
        data_store_id=data_store_id,
    )
    operation = client.create_data_store(request=request)

    # Make the request
    # The try block is necessary to prevent execution from haulting due to an error being thrown when the datastore takes a while to instantiate
    try:
        response = operation.result(timeout=90)
    except:
        print("long-running operation")

# %%
# The datastore name can only contain lowercase letters, numbers, and hyphens
DATASTORE_NAME = "harry-potter-books"
DATASTORE_ID = f"{DATASTORE_NAME}-id"

# %%
create_data_store(PROJECT_ID, LOCATION, DATASTORE_NAME, DATASTORE_ID)

# %% [markdown]
# ### Import Document

# %%
def import_documents(
    project_id: str,
    location: str,
    data_store_id: str,
    gcs_uri: str,
):
    # Create a client
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )
    client = discoveryengine.DocumentServiceClient(client_options=client_options)

    # The full resource name of the search engine branch.
    # e.g. projects/{project}/locations/{location}/dataStores/{data_store_id}/branches/{branch}
    parent = client.branch_path(
        project=project_id,
        location=location,
        data_store=data_store_id,
        branch="default_branch",
    )

    source_documents = [f"{gcs_uri}/*"]

    request = discoveryengine.ImportDocumentsRequest(
        parent=parent,
        gcs_source=discoveryengine.GcsSource(
            input_uris=source_documents, data_schema="content"
        ),
        # Options: `FULL`, `INCREMENTAL`
        reconciliation_mode=discoveryengine.ImportDocumentsRequest.ReconciliationMode.INCREMENTAL,
    )

    # Make the request
    operation = client.import_documents(request=request)

    response = operation.result()

    # Once the operation is complete,
    # get information from operation metadata
    metadata = discoveryengine.ImportDocumentsMetadata(operation.metadata)

    # Handle the response
    return operation.operation.name

# %%
# print(gcs_uri)

source_documents_gs_uri = (
"gs://my-project-0004-346516/matchingengine/books")

import_documents(PROJECT_ID, LOCATION, DATASTORE_ID, source_documents_gs_uri)
    
# "gs://my-project-0004-346516/matchingengine/books/Book2_The_Chamber_of_Secrets.pdf",
# "gs://my-project-0004-346516/matchingengine/books/Book3_The_Prisoner_of_Azkaban.pdf",
# "gs://my-project-0004-346516/matchingengine/books/Book4_The_Goblet_of_Fire.pdf",
# "gs://my-project-0004-346516/matchingengine/books/Book5_The_Order_of_the_Phoenix.pdf",
# "gs://my-project-0004-346516/matchingengine/books/Book6_The_HalfBlood_Prince.pdf",
# "gs://my-project-0004-346516/matchingengine/books/Book7_The_Deathly_Hallows.pdf",

# %% [markdown]
# ### Create a Search Engine
# This is used to set the search_tier to enterprise and to enable advanced LLM features.
#
# Enterprise tier is required to get extractive answers from a search query and advanced LLM features are required to sumarize search results.

# %%
def create_engine(
    project_id: str, location: str, data_store_name: str, data_store_id: str
):
    # Create a client
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if location != "global"
        else None
    )
    client = discoveryengine.EngineServiceClient(client_options=client_options)

    # Initialize request argument(s)
    config = discoveryengine.Engine.SearchEngineConfig(
        search_tier="SEARCH_TIER_ENTERPRISE", search_add_ons=["SEARCH_ADD_ON_LLM"]
    )

    engine = discoveryengine.Engine(
        display_name=data_store_name,
        solution_type="SOLUTION_TYPE_SEARCH",
        industry_vertical="GENERIC",
        data_store_ids=[data_store_id],
        search_engine_config=config,
    )

    request = discoveryengine.CreateEngineRequest(
        parent=discoveryengine.DataStoreServiceClient.collection_path(
            project_id, location, "default_collection"
        ),
        engine=engine,
        engine_id=engine.display_name,
    )

    # Make the request
    operation = client.create_engine(request=request)
    response = operation.result(timeout=90)

# %%
create_engine(PROJECT_ID, LOCATION, DATASTORE_NAME, DATASTORE_ID)

# %% [markdown]
# ### Query your Datastore

# %%
from typing import List


def search_sample(
    project_id: str,
    location: str,
    data_store_id: str,
    search_query: str,
) -> List[discoveryengine.SearchResponse]:
    #  For more information, refer to:
    # https://cloud.google.com/generative-ai-app-builder/docs/locations#specify_a_multi-region_for_your_data_store
    client_options = (
        ClientOptions(api_endpoint=f"{location}-discoveryengine.googleapis.com")
        if LOCATION != "global"
        else None
    )

    # Create a client
    client = discoveryengine.SearchServiceClient(client_options=client_options)

    # The full resource name of the search engine serving config
    # e.g. projects/{project_id}/locations/{location}/dataStores/{data_store_id}/servingConfigs/{serving_config_id}
    serving_config = client.serving_config_path(
        project=project_id,
        location=location,
        data_store=data_store_id,
        serving_config="default_config",
    )

    # Optional: Configuration options for search
    # Refer to the `ContentSearchSpec` reference for all supported fields:
    # https://cloud.google.com/python/docs/reference/discoveryengine/latest/google.cloud.discoveryengine_v1.types.SearchRequest.ContentSearchSpec
    content_search_spec = discoveryengine.SearchRequest.ContentSearchSpec(
        # For information about snippets, refer to:
        # https://cloud.google.com/generative-ai-app-builder/docs/snippets
        snippet_spec=discoveryengine.SearchRequest.ContentSearchSpec.SnippetSpec(
            return_snippet=True
        ),
        # For information about search summaries, refer to:
        # https://cloud.google.com/generative-ai-app-builder/docs/get-search-summaries
        summary_spec=discoveryengine.SearchRequest.ContentSearchSpec.SummarySpec(
            summary_result_count=5,
            include_citations=True,
            ignore_adversarial_query=True,
            ignore_non_summary_seeking_query=True,
        ),
    )

    # Refer to the `SearchRequest` reference for all supported fields:
    # https://cloud.google.com/python/docs/reference/discoveryengine/latest/google.cloud.discoveryengine_v1.types.SearchRequest
    request = discoveryengine.SearchRequest(
        serving_config=serving_config,
        query=search_query,
        page_size=10,
        content_search_spec=content_search_spec,
        query_expansion_spec=discoveryengine.SearchRequest.QueryExpansionSpec(
            condition=discoveryengine.SearchRequest.QueryExpansionSpec.Condition.AUTO,
        ),
        spell_correction_spec=discoveryengine.SearchRequest.SpellCorrectionSpec(
            mode=discoveryengine.SearchRequest.SpellCorrectionSpec.Mode.AUTO
        ),
    )

    response = client.search(request)
    return response

# %%
query = "Who is the best friend of harry potter?"

print(search_sample(PROJECT_ID, LOCATION, DATASTORE_ID, query).summary.summary_text)
# Out:
# Ron Weasley and Hermione Granger are Harry Potter's best friends at Hogwarts [1, 2].

# %% [markdown]
# ### Code to Run through all the Q&A and RAG

# %%
Gemini_query
generate_pro(Gemini_query)
# Out:
# 'The information provided does not specify what Harry did to get him temporarily expelled from Hogwarts. It only mentions that he did serious magic, which broke the Decree for the  Restriction of Underage Wizardry.'

# %%
import pandas as pd
import time

filename = "./harry_potte_qa_output.csv"
df_qa_VertexSearch = pd.read_csv(filename, sep ="|")

System_Prompts = """ You are an expert in reading harry potter books, but only provide evidences from the information provide and do not use an other information
so here are some search results : 
"""

Question_Prompts = """ -- Based on information above help to answer following user question
"""


for i in range(0, len(df_qa_VertexSearch)):
    
    print("iteration #", i)
    time.sleep(2)  
    
    RAG_query = df_qa_VertexSearch.loc[i,'Question'] 
    
    print(RAG_query)
    RAG_results = search_sample(PROJECT_ID, LOCATION, DATASTORE_ID, RAG_query).summary.summary_text
    
    Gemini_query = System_Prompts + " " + RAG_results + " " + Question_Prompts + " " + df_qa_VertexSearch.loc[i,'Question']
    
    try:        
        df_qa_VertexSearch.loc[i, "Gemini_pro_model_output_v1"] = generate_pro(Gemini_query)
        df_qa_VertexSearch.loc[i, "palm_bison32k_output_v1"] = generate_palm_bison32k(Gemini_query)

    except:
        df_qa_VertexSearch.loc[i, "Gemini_pro_model_output_v1"] = "No answer found"
        df_qa_VertexSearch.loc[i, "palm_bison32k_output_v1"] = "No answer found"
        print("long-running operation")



output1 = "./harry_potter_qa_model_RAG_VertexSearch.csv"

df_qa_VertexSearch.to_csv(output1)
# Out:
# iteration # 0
# What is the name of the magical creature that can only be seen by those who have witnessed death?
# Response from Model:  Based on the information provided, there is no magical creature that can only be seen by those who have witnessed death.
# iteration # 1
# What is the name of the school newspaper at Hogwarts?
# Response from Model:  The name of the school newspaper at Hogwarts is the Daily Prophet.
# iteration # 2
# What is the name of the magical map that shows the entire layout of Hogwarts?
# Response from Model:  The Marauder's Map is the magical map that shows the entire layout of Hogwarts.
# iteration # 3
# Which Hogwarts house does Luna Lovegood belong to?
# Response from Model:  The provided text does not specify which Hogwarts house Luna Lovegood belongs to.
# iteration # 4
# What magical creature is known for guarding Gringott's Bank?
# Response from Model:  Dragons
# iteration # 5
# What is the primary ingredient in Polyjuice potion?
# Response from Model:  The primary ingredient in Polyjuice potion is human hair.
# iteration # 6
# What is the name of the three-headed dog guarding the trapdoor in Harry Potter and the Sorcerer's Stone?
# Response from Model:  Fluffy
# iteration # 7
# What position does Harry play in Quidditch?
# Response from Model:  The provided text does not specify what position Harry plays in Quidditch.
# iteration # 8
# Where did Hermione hold the first meeting for students interested in joining Dumbledore's Army?
# Response from Model:  The Room of Requirement.
# iteration # 9
# What is Hermione's cat's name?
# Response from Model:  The provided information does not specify the name of Hermione's cat.
# iteration # 10
# Which pub in London conceals the entrance to Diagon Alley?
# Response from Model:  The information provided does not specify which pub in London conceals the entrance to Diagon Alley, therefore I cannot answer this question.
# iteration # 11
# What eavesdropping tool did Fred and George invent in Harry Potter and the Order of the Phoenix?
# Response from Model:  Based on the information provided, Fred and George invented the Pocket Sneakoscope, a small, round device that spins and glows when it detects eavesdropping.
# iteration # 12
# Who is the Slytherin ghost?
# Response from Model:  The Slytherin ghost is the Bloody Baron.
# iteration # 13
# What does Harry name his children?
# Response from Model:  Harry names his children Albus Severus and James Sirius.
# iteration # 14
# Where would you look to find a bezoar?
# Response from Model:  The provided information does not specify where to find a bezoar. It only mentions that a bezoar is a stone taken from the stomach of a goat.
# iteration # 15
# In the book version of Harry Potter and the Sorcerer's Stone, what is the name of Dudley's friend who goes to the zoo with the Dursleys and Harry?
# Response from Model:  According to the information provided, Dudley's best friend is Piers Polkiss, and Piers is mentioned as Dudley's best friend specifically in the book version of Harry Potter and the Sorcerer's Stone. Therefore, it can be concluded that in the book version of Harry Potter and the Sorcerer's Stone, Dudley's friend who goes to the zoo with the Dursleys and Harry is Piers Polkiss.
# iteration # 16
# And what type of animal does Harry accidentally set free while they're at the zoo?
# Response from Model:  According to the information provided, Harry accidentally set a boa constrictor free at the zoo.
# iteration # 17
# What is the name of the couple that attends dinner at the Dursley's when Dobby shows up to stop Harry from retuning to Hogwarts?
# Response from Model:  The name of the couple that attends dinner at the Dursley's when Dobby shows up to stop Harry from retuning to Hogwarts is not mentioned in the provided information.
# iteration # 18
# What does the boggart turn into when Mrs. Weasley sees it?
# Response from Model:  According to the information provided, the boggart turns into a dementor when it sees Mrs. Weasley.
# iteration # 19
# In the book version of Harry Potter and the Half-Blood Prince, who finds Harry on the Hogwarts Express after Malfoy breaks his nose and leaves him under the Invisibility Cloak?
# Response from Model:  Based on the information provided, it is Snape who finds Harry on the Hogwarts Express after Malfoy breaks his nose and leaves him under the Invisibility Cloak.
# iteration # 20
# How was Hermione able to take extra lessons?
# Response from Model:  Hermione was able to take extra lessons by using a Time-Turner.
# iteration # 21
# Who is manipulated into vandalizing Hogwarts with messages about the Chamber of Secrets?
# Response from Model:  Ginny Weasley
# iteration # 22
# Which insect is Ron afraid of?
# Response from Model:  The provided text does not specify which insect Ron is afraid of.
# iteration # 23
# What’s the name of Hagrid’s half-brother?
# Response from Model:  The provided information states that Hagrid's half-brother is Charlie.
# iteration # 24
# What is Hermione’s patronus?
# Response from Model:  The information you have provided does not include the answer to what Hermione's patronus is.
# iteration # 25
# What is the name of the Weasley twins’ magic joke shop?
# Response from Model:  The Weasley twins' magic joke shop is called Gambol and Japes Wizarding Joke Shop.
# iteration # 26
# Where was Harry Potter born?
# Response from Model:  The provided text does not specify where Harry Potter was born.
# iteration # 27
# What is Professor McGonagall’s animagus?
# Response from Model:  The provided text does not contain information about Professor McGonagall's animagus.
# iteration # 28
# What is the name of the Gryffindor ghost?
# Response from Model:  The name of the Gryffindor ghost is Nearly Headless Nick, or Sir Nicholas de Mimsy-Porpington.
# iteration # 29
# What type of creature is Fluffy?
# Response from Model:  The provided information does not specify what type of creature Fluffy is.
# iteration # 30
# Who is Harry's godfather?
# Response from Model:  According to the provided information, Harry's godfather is Sirius Black.
# iteration # 31
# What is Voldemort's real name?
# Response from Model:  Voldemort's real name is Tom Marvolo Riddle.
# iteration # 32
# What is the British term for a nonmagical person?
# Response from Model:  The British term for a nonmagical person is Muggles.
# iteration # 33
# Who is NOT in Gryffindor: Harry Potter, Ron Weasley, Draco Malfoy, or Ginny Weasley?
# Response from Model:  Based on the information provided, Draco Malfoy is not in Gryffindor.
# iteration # 34
# What is Harry's middle name?
# Response from Model:  Based on the information provided, there is no evidence of Harry's middle name.
# iteration # 35
# What year do Hogwarts students take O.W.L.s?
# Response from Model:  Based on the provided information, Hogwarts students take O.W.L.s in the fifth year.
# iteration # 36
# Who sent Harry his Firebolt?
# Response from Model:  The text provided does not explicitly state who sent Harry the Firebolt. Ron believes it was Dumbledore, but Harry thinks Dumbledore would not spend so much money on him. Therefore, the question of who sent Harry the Firebolt remains unanswered based on the provided information.
# iteration # 37
# Which Weasley dies during the final battle of Hogwarts?
# Response from Model:  Fred Weasley dies during the final battle of Hogwarts.
# iteration # 38
# What magazine does Xenophilius Lovegood publish?
# Response from Model:  The text provided does not include information about what magazine Xenophilius Lovegood publishes.
# iteration # 39
# Which incantation can levitate an object?
# Response from Model:  The incantation "Wingardium Leviosa" can levitate an object. This is evident in the first book of the Harry Potter series, Harry Potter and the Philosopher's Stone, when Hermione Granger uses it to levitate a feather during a Charms class.
# iteration # 40
# What did Harry do to get him temporarily expelled from Hogwarts?
# Response from Model:  According to the information provided, Harry performed serious magic, which broke the Decree for the Restriction of Underage Wizardry. This resulted in his near expulsion from Hogwarts.
# iteration # 41
# What's the address of the Black family home?
# Response from Model:  The provided text does not specify the address of the Black family home, so I cannot answer this question.
# iteration # 42
# When is Harry's birthday?
# Response from Model:  The provided text does not specify when Harry's birthday is.
# iteration # 43
# What is the correct birth order of the Weasley children?
# Response from Model:  Based on the information provided, we can conclude that the correct birth order of the Weasley children is:
# 1. Percy
# 2. Mr. Weasley
# 3. Fred
# 4. George
# iteration # 44
# Who anonymously sends Harry his father's Invisibility Cloak on Christmas?
# Response from Model:  It is Dumbledore who anonymously sends Harry his father's Invisibility Cloak on Christmas.
# iteration # 45
# What is the animal symbol of Ravenclaw?
# Response from Model:  According to the information provided, the animal symbol of Ravenclaw is an eagle.
# iteration # 46
# What is the name of Hagrid's boarhound dog?
# long-running operation
# iteration # 47
# And what about his pet dragon?
# Response from Model:  There is no mention of a pet dragon in the provided text.
# iteration # 48
# Who betrays Lily and James Potter: Moony, Professor Snape, Padfoot, or Wormtail?
# Response from Model:  The answer is: Wormtail
#
# The passage says "It was Peter Pettigrew, also known as Wormtail, who betrayed Lily and James Potter.". So we know that Wormtail is the one who betrays Lily and James Potter.
# iteration # 49
# What is the name of the Weasley family home?
# Response from Model:  The Burrow
# iteration # 50
# What potion gives good luck to those who drink it?
# Response from Model:  The provided information does not mention any potion that gives good luck to those who drink it.
# iteration # 51
# What is the maiden name of sisters Lily Potter and Petunia Dursley?
# Response from Model:  The maiden name of sisters Lily Potter and Petunia Dursley is Evans.
# iteration # 52
# Who is NOT in Slytherin: Lavender Brown, Pansy Parkinson, Blaise Zabini, or Greggory Goyle?
# Response from Model:  The provided information does not specify which house Lavender Brown belongs to, so it is not possible to determine whether she is in Slytherin or not.
# iteration # 53
# What day did James and Lily Potter die?
# Response from Model:  The provided information does not mention the specific day on which James and Lily Potter died.
# iteration # 54
# What class does Professor McGonagall teach?
# long-running operation
# iteration # 55
# Who does Bill Weasley marry?
# long-running operation
# iteration # 56
# What kind of wood is Harry's first wand made out of?
# Response from Model:  Yew
# iteration # 57
# How many Horcruxes did Voldemort create intentionally?
# long-running operation
# iteration # 58
# Who wrote A History of Magic?
# long-running operation
# iteration # 59
# Who kills Dobby?
# Response from Model:  The provided text does not specify who kills Dobby.
# iteration # 60
# What house is Justin Finch-Fletchley in?
# Response from Model:  The provided information states that "Justin Finch-Fletchley is in Hufflepuff".
# iteration # 61
# What does Hagrid use to channel the pieces of his wand once it's been broken?
# long-running operation
# iteration # 62
# How many players are on a Quidditch team?
# long-running operation
# iteration # 63
# What children's book contains the story of the Deathly Hallows?
# Response from Model:  There is no information in the provided text about which children's book contains the story of the Deathly Hallows. It only states that the story of the Deathly Hallows is not in any of the Harry Potter books.
# iteration # 64
# Where is the entrance to the Chamber of Secrets hidden?
# Response from Model:  The text does not specify where the entrance to the Chamber of Secrets is hidden.
# iteration # 65
# What teleportation magic do sixth-years learn at Hogwarts?
# Response from Model:  The provided text does not mention which teleportation magic sixth-years learn at Hogwarts.
# iteration # 66
# What kind of magical creature is Aragog?
# Response from Model:  Based on the provided information, Aragog is a magical creature known as a giant spider.
# iteration # 67
# What is Ron's favorite Quidditch team?
# Response from Model:  The provided text does not mention Ron's favorite Quidditch team.
# iteration # 68
# When is Neville's birthday?
# Response from Model:  I cannot find the answer to when Neville's birthday is in the provided text.
# iteration # 69
# What is James Potter's Marauder nickname?
# Response from Model:  James Potter's Marauder nickname is Prongs.
# iteration # 70
# How is the Grey Lady related to Rowena Ravenclaw?
# Response from Model:  The Grey Lady is the ghost of Rowena Ravenclaw, one of the four founders of Hogwarts.
# iteration # 71
# What does Charlie Weasley do for a living after graduation?
# Response from Model:  Charlie Weasley studies dragons in Romania after graduating.
# iteration # 72
# What name does Buckbeak get after being saved from execution?
# Response from Model:  The provided text does not contain information about the name Buckbeak gets after being saved from execution.
# iteration # 73
# What is Dean Thomas's favorite sport?
# Response from Model:  Dean Thomas's favorite sport is soccer, as mentioned in the search results.
# iteration # 74
# What does Harry do with his winnings from the Triwizard Tournament?
# Response from Model:  Harry exercises self-control and doesn't spend his winnings all at once. He refills his money bag with gold Galleons, silver Sickles, and bronze Knuts from his vault at Gringotts. He has a small fortune buried deep under London.
# iteration # 75
# What is Voldemort's mother's name?
# Response from Model:  Voldemort's mother's name is Merope Gaunt.
# iteration # 76
# Who are the Chasers on the Gryffindor Quidditch team when Harry joins?
# Response from Model:  The Chasers on the Gryffindor Quidditch team when Harry joins are Alicia Spinner, Angelina Johnson, and Katie Bell.
# iteration # 77
# Who is the first person to ever successfully break into Gringotts?
# Response from Model:  The provided information does not contain any evidence about the first person to ever successfully break into Gringotts.
# iteration # 78
# How is Bellatrix related to Tonks?
# Response from Model:  Bellatrix is Tonks's aunt.
# iteration # 79
# What family does Winky the house-elf belong to before working at Hogwarts?
# Response from Model:  The provided information does not mention Winky the house-elf's family or previous employment before working at Hogwarts.
# iteration # 80
# What is the full name of Nearly Headless Nick?
# Response from Model:  Sir Nicholas de Mimsy-Porpington
# iteration # 81
# How old was the Sorcerer's Stone co-creator Nicolas Flamel when he decided to destroy it?
# Response from Model:  The provided text does not specify the age of Nicolas Flamel when he decided to destroy the Sorcerer's Stone.
# iteration # 82
# Monkshood and wolfsbane are the same plant, also known as what?
# Response from Model:  Based on the information provided, monkshood and wolfsbane are the same plant, also known as aconite.
# iteration # 83
# How many staircases does Hogwarts have?
# Response from Model:  According to the provided information, Hogwarts has 142 staircases.
# iteration # 84
# In the Hall of Prophecy, there are rows and rows of glowing orbs. Which row contains the prophecy about Harry and Voldemort?
# Response from Model:  The provided information states that "The prophecy about Harry and Voldemort is in the first row". Therefore, the prophecy about Harry and Voldemort is in the first row of glowing orbs in the Hall of Prophecy.
# iteration # 85
# How many possible Quidditch fouls are there?
# Response from Model:  Based on the information provided, there are 14 possible Quidditch fouls.
# iteration # 86
# Dumbledore has a scar above his left knee that is a perfect map of what?
# Response from Model:  According to the information provided, Dumbledore has a scar above his left knee that is a perfect map of the London Underground.
# iteration # 87
# For Harry's 17th birthday, what color did Hermione turn the leaves of the Weasleys’ crabapple tree?
# Response from Model:  Gold
# iteration # 88
# Cedric Diggory let Harry use the prefect's bathroom in The Goblet of Fire. What man's statue is next to the lavatory entrance?
# Response from Model:  The provided information does not specify the name of the man whose statue is next to the lavatory entrance in the prefect's bathroom that Cedric Diggory let Harry use in The Goblet of Fire.
# iteration # 89
# In Harry Potter and the Prisoner of Azkaban, how do Hermione, Harry, and Ron find Crookshanks?
# Response from Model:  - Harry crawls down a tunnel.
# - Hermione slithers down beside him.
# iteration # 90
# What is the max speed of a Firebolt broomstick?
# Response from Model:  The provided text doesn't specify the maximum speed of the Firebolt broomstick. It only states that it can accelerate to 150 miles per hour in ten seconds.
# iteration # 91
# In the Quidditch World Cup, Ireland's team had three main chasers: Mullet, Troy, and Moran. Which one scored the first goal?
# Response from Model:  The provided text only mentioned the red ball (Quaffle) that scores goals but does not include details about the Quidditch World Cup or specific Irish players. Therefore, I cannot answer the question.
# iteration # 92
# Voldemort stole Helga Hufflepuff's cup from an old woman named Hepzibah Smith. What was the name of her house-elf?
# Response from Model:  The name of Hepzibah Smith's house-elf is not mentioned in the provided information.
# iteration # 93
# Ginny Weasley bought a pet Pygmy Puff from her older brothers' joke shop. What did she name it?
# Response from Model:  According to the information provided, Ginny Weasley named her pet Pygmy Puff Arnold.
# iteration # 94
# Who killed the Grey Lady?
# Response from Model:  The information provided does not state who killed the Grey Lady.
# iteration # 95
# What was the name of the Quidditch team on the sock Mrs. Weasley tries to give to Harry?
# Response from Model:  The provided text does not specify the name of the Quidditch team on the sock Mrs. Weasley tries to give to Harry. It only mentions that the sock has the Gryffindor lion knitted on the front.
# iteration # 96
# What color is Teddy Lupin's hair when he is born?
# Response from Model:  The provided information does not specify the color of Teddy Lupin's hair when he is born.
# iteration # 97
# Which scent attracts Hermione Granger?
# Response from Model:  The provided information does not specify which scent attracts Hermione Granger.
# iteration # 98
# How many times did Gilderoy Lockhart win Witch Weekly's Most Charming Smile Award?
# Response from Model:  Gilderoy Lockhart won the Witch Weekly's Most Charming Smile Award five times in a row.
# iteration # 99
# What is the core of Draco Malfoy's wand?
# Response from Model:  The core of Draco Malfoy's wand is unicorn hair.
# iteration # 100
# Who is the matron of the orphanage where Voldemort grows up?
# Response from Model:  The provided text does not mention the matron of the orphanage where Voldemort grows up, so I cannot answer this question from the provided context.
# iteration # 101
# What was the name of the orphanage where Lord Voldemort grew up?
# Response from Model:  The provided text states that the name of the orphanage where Lord Voldemort grew up is unknown.
# iteration # 102
# In Harry Potter and the Prisoner of Azkaban, whose portrait replaces the Fat Lady after she is attacked?
# Response from Model:  In Harry Potter and the Prisoner of Azkaban, Sir Cadogan's portrait replaces the Fat Lady after she is attacked.
# iteration # 103
# What does Professor Kettleburn wish to do after retiring from Hogwarts?
# Response from Model:  Based on the information provided, Professor Kettleburn wishes to enjoy more time with his remaining limbs after retiring from Hogwarts.
# iteration # 104
# What is Lockhart's favorite color?
# Response from Model:  The provided information does not specify Lockhart's favorite color.
# iteration # 105
# In Harry Potter and the Chamber of Secrets, where were Harry, Hermione, and Ron coming from when they found Mrs. Norris petrified?
# Response from Model:  The text states that Harry, Ron, and Hermione were following the other Gryffindors to Gryffindor Tower when they found Mrs. Norris petrified.
# iteration # 106
# What does Hermione say Jupiter's largest moon is?
# Response from Model:  The provided text does not contain any information about Hermione's statement on Jupiter's largest moon.
# iteration # 107
# When did Harry learn Accio?
# Response from Model:  According to the information provided, Harry learned Accio in Harry Potter and the Sorcerer's Stone.
# iteration # 108
# What is Lily Potter's birthday?
# Response from Model:  The provided text does not contain Lily Potter's birthday.
# iteration # 109
# What is Snape's birthday?
# Response from Model:  The provided text does not specify Snape's birthday.
# iteration # 110
# Why did Hermione miss the lesson on Cheering Charms?
# Response from Model:  Hermione missed the lesson on Cheering Charms because she was pretending to have broken the rules to get Harry and Ron out of trouble.
# iteration # 111
# In Harry Potter and the Half-Blood Prince, in the Weasleys' magical clock, what are all of the hands pointed to when Harry arrives at the Burrow?
# Response from Model:  Based on the information provided, the passage only mentions that two hands of the Weasleys' magical clock are pointing to the words "Home" and "Travel" when Harry arrives at the Burrow. It does not mention the positions or labels of any other hands on the clock.
# iteration # 112
# What does Ginny say Ron has a tattoo of?
# Response from Model:  The provided text does not mention anything about Ginny saying Ron has a tattoo.
# iteration # 113
# What is the middle name of Harry's daughter, Lily?
# Response from Model:  The provided information does not mention the middle name of Harry Potter's daughter, Lily.
# iteration # 114
# In Harry Potter and the Prisoner of Azkaban, where is the secret passage from Hogwarts to Honeydukes hidden?
# Response from Model:  In Harry Potter and the Prisoner of Azkaban, the secret passage from Hogwarts to Honeydukes is hidden behind a door at the top of the stairs.
# iteration # 115
# What is Ron's middle name?
# Response from Model:  The provided text does not specify Ron's middle name.
# iteration # 116
# Who is the second Peverell brother?
# Response from Model:  The provided text does not mention anything about the second Peverell brother. So I cannot answer this question from the provided text.
# iteration # 117
# What is the magical equipment store in Hogsmeade?
# Response from Model:  The magical equipment store in Hogsmeade is called Dervish and Banges.
# iteration # 118
# Who is the Hogwarts student who cursed herself to get rid of her acne?
# Response from Model:  The information provided does not specify which Hogwarts student cursed herself to get rid of her acne.
# iteration # 119
# Who is Neville Longbottom's father?
# Response from Model:  Neville Longbottom's father is Frank Longbottom.
# iteration # 120
# What is Ginny's full name?
# Response from Model:  The information provided does not contain Ginny's full name, so I cannot answer this question from the provided context.
# iteration # 121
# What is the name of the all-female Quidditch team?
# Response from Model:  The provided information states that there is no all-female Quidditch team, so I cannot provide a team name.
# iteration # 122
# Who is the the third Peverell brother?
# long-running operation
# iteration # 123
# What is Hermione’s middle name?
# Response from Model:  The provided information states that "Hermione's middle name is Jean". Therefore, Hermione's middle name is Jean.
# iteration # 124
# Who is the catlike magical creature with the tail of a lion?
# Response from Model:  Based on the information provided, there is no mention of a catlike magical creature with the tail of a lion.
# iteration # 125
# What is Dumbledore’s favorite Muggle sweet?
# Response from Model:  The provided text does not specify Dumbledore's favorite Muggle sweet.
# iteration # 126
# What does Mr. Weasley call Mrs. Weasley when they’re alone together?
# Response from Model:  The text you provided does not contain any information about what Mr. Weasley calls Mrs. Weasley when they are alone together.
# iteration # 127
# What is the spell to turn off Lumos?
# Response from Model:  Based on the provided information, the spell to turn off Lumos is Nox.
# iteration # 128
# What is the color of Crookshanks’s fur?
# Response from Model:  Based on the information provided, Crookshanks's fur is black.
# iteration # 129
# Who is Nicolas Flamel’s wife?
# Response from Model:  Nicolas Flamel's wife is Perenelle.
# iteration # 130
# What is the largest ball used in Quidditch?
# Response from Model:  The largest ball used in Quidditch is the Quaffle.
# iteration # 131
# What is Dumbledore’s favorite flavor of jam?
# Response from Model:  The provided text does not specify Dumbledore's favorite flavor of jam.
# iteration # 132
# What is Professor Trelawney’s first name?
# Response from Model:  Professor Trelawney's first name is Sibyl.
# iteration # 133
# What is the number of Knuts in a Sickle?
# Response from Model:  The number of Knuts in a Sickle is 29.
# iteration # 134
# Who are the employees of the Department of Mysteries?
# Response from Model:  Based on the information provided, the employees of the Department of Mysteries are not known.
# iteration # 135
# Who is Bill and Fleur's eldest child?
# Response from Model:  The provided text does not specify the name of Bill and Fleur's eldest child.
# iteration # 136
# What is Dumbledore's middle name?
# Response from Model:  The provided text does not mention Dumbledore's middle name, so I cannot answer this question.
# iteration # 137
# What is the Christmas event held to celebrate the Triwizard Tournament?
# Response from Model:  The Triwizard Tournament Christmas event is known as the "End of Term Feast."
# iteration # 138
# Which house is Hannah Abbott sorted into?
# Response from Model:  Hannah Abbott is sorted into Hufflepuff.
#
# Evidence from the provided text:
# - "Hannah Abbott is sorted into Hufflepuff."
# iteration # 139
# In Harry Potter and the Prisoner of Azkaban, what name does Harry give Stan when he gets on the Knight Bus?
# Response from Model:  The provided text states that "Harry doesn't give Stan a name when he gets on the Knight Bus."
# iteration # 140
# What mascot do the Bulgarians bring to the Quidditch World Cup?
# Response from Model:  The provided text states that "The Bulgarians bring a mascot to the Quidditch World Cup", but it does not specify what the mascot is.
# iteration # 141
# What does S.P.E.W. stand for?
# Response from Model:  S.P.E.W. stands for the Society for the Promotion of Elfish Welfare.
# iteration # 142
# What happened to Neville's parents?
# long-running operation
# iteration # 143
# During the third task in Harry Potter and the Goblet of Fire, what is the answer to the sphinx's riddle?
# Response from Model:  "water"
# iteration # 144
# How was Rita Skeeter listening to private conversations at Hogwarts all year?
# Response from Model:  According to the information provided, Rita Skeeter was listening to private conversations at Hogwarts all year by using a Time-Turner.
# iteration # 145
# What does the Howler that Aunt Petunia receives say?
# Response from Model:  According to the information provided, the Howler that Aunt Petunia receives says two things:
# 1. It tells her that she didn't tell them where the maniac escaped from.
# 2. It also warns her that if the Ministry gets wind of any more magic in Privet Drive, Harry would face expulsion from Hogwarts.
# iteration # 146
# Who tells Harry about the Room of Requirement?
# Response from Model:  Hermione tells Harry about the Room of Requirement.
# iteration # 147
# In Harry Potter and the Goblet of Fire, what is the name of the Muggle whom Voldemort kills inside the Riddle House?
# Response from Model:  Based on the information provided, the name of the Muggle whom Voldemort kills inside the Riddle House is Frank Bryce.
# iteration # 148
# How did Harry, Ron, and Hermione communicate to the other members of Dumbledore's Army that they were meeting?
# Response from Model:  This context does not mention anything about Harry, Ron, and Hermione communicating with other members of Dumbledore's Army, so I cannot answer this question from the provided context.
# iteration # 149
# While Neville is at St. Mungo's, what does his mom give him as a gift?
# Response from Model:  The provided text does not specify what gift Neville's mom gives him while he is at St. Mungo's.
# iteration # 150
# What is the name of the centaur that replaces Trelawney as the professor of Divination?
# Response from Model:  The provided information does not mention any centaur replacing Trelawney as the Divination professor.
# iteration # 151
# Why does the Order of the Phoenix move out of 12 Grimmauld Place after Sirius's death?
# Response from Model:  The provided information states that "The Order of the Phoenix moves out of 12 Grimmauld Place after Sirius's death." However, it does not specify the reason for the move. Therefore, I cannot answer this question from the provided information.
# iteration # 152
# What nickname does Ginny give Fleur in Harry Potter and the Half-Blood Prince?
# Response from Model:  The provided context does not mention any nickname Ginny gives Fleur in "Harry Potter and the Half-Blood Prince" or any other book in the series.
# iteration # 153
# How did Ginny end up at the Slug Club meeting on the Hogwarts Express?
# Response from Model:  According to the provided information, Ginny ended up at the Slug Club meeting on the Hogwarts Express because Slughorn invited her to his compartment.
# iteration # 154
# During his first visit with Tom Riddle, what does Dumbledore have Tom take out of his wardrobe at the orphanage?
# Response from Model:  Based on the provided information, when Dumbledore first visits Tom Riddle at the orphanage, he has Tom take out a strange object from his wardrobe. Unfortunately, the exact nature of the object is not specified in the provided information.
# iteration # 155
# While learning to Apparate, what are the "three D's" everyone must remember?
# Response from Model:  The information you have provided does not mention the "three D's" that everyone must remember while learning to Apparate.
# iteration # 156
# What's Ron's cover story as to why he's not at Hogwarts in Harry Potter and the Deathly Hallows?
# Response from Model:  Ron's cover story is that he is missing.
# iteration # 157
# What fake name does Harry use while attending Bill and Fleur's wedding in disguise in Harry Potter and the Deathly Hallows?
# Response from Model:  According to the provided information, Harry uses the fake name "Brendan" while attending Bill and Fleur's wedding in disguise.
# iteration # 158
# After breaking into the Ministry of Magic, what does Harry steal from Umbridge's office in Harry Potter and the Deathly Hallows?
# Response from Model:  Based on the information provided, after breaking into the Ministry of Magic in Harry Potter and the Deathly Hallows, Harry steals a Pensieve from Umbridge's office.
# iteration # 159
# What quote is written on James and Lily's grave in Godric's Hollow?
# Response from Model:  The provided search results indicate that there is no quote written on James and Lily's grave in Godric's Hollow.
# iteration # 160
# How do the Death Eaters find Harry, Hermione, and Ron in the forest before they are taken to Malfoy Manor in the book Harry Potter and the Deathly Hallows?
# Response from Model:  There is no mention of how the Death Eaters find Harry, Hermione, and Ron in the forest before they are taken to Malfoy Manor in the provided information.
# iteration # 161
# How does Peter Pettigrew die?
# Response from Model:  Peter Pettigrew is blown to smithereens by Sirius Black, as per the information provided.
# iteration # 162
# What caused Ariana Dumbledore to stop using magic?
# Response from Model:  The provided information does not mention what caused Ariana Dumbledore to stop using magic.
# iteration # 163
# How do you get into Ravenclaw's common room?
# Response from Model:  Based on the information provided, the text does not provide specific details on how to gain access to Ravenclaw's common room.
# iteration # 164
# And finally, how do Lily and Snape meet for the first time?
# Response from Model:  Based on the information provided, Snape sees Lily crossing the grounds with Madam Pomfrey when they meet for the first time.

# %% [markdown]
# ## Generating factual question about the topics

# %%
import os
import vertexai
from vertexai.preview.language_models import TextGenerationModel
from vertexai.preview.generative_models import GenerativeModel, Part
Region = "us-central1"
GCP_PROJECT= PROJECT_ID=project_id='my-project-0004-346516'

vertexai.init()

def generate_pro(input_prompt):
    model = GenerativeModel("gemini-pro")
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1
    },stream=True,)
    
    all_response  = []
    
    for response in responses:
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))

# %%
from vertexai.preview.vision_models import ImageGenerationModel

imagen_model = ImageGenerationModel.from_pretrained("imagegeneration@005")

# %%
prev_question = ""
new_topic = ""
LOCATION='global'

for i in range(0,20):

    query = "Generate a question based on the facts from the search "
    
    full_query = query + "  do not generate repeated questions /n \n  but you may choose this topic here :: " + str(new_topic)
    
    question = search_sample(PROJECT_ID, LOCATION, DATASTORE_ID, full_query).summary.summary_text
    print(question)
    
    if prev_question == question :
        input_prompt = " do not generate topic related to this :: -- " + new_topic  + \
        "   give me a two or three word topic about happy potter "
        new_topic = generate_pro(input_prompt)
        print("new_topic", new_topic)
    
    if prev_question != question :
        # input_question = "What is a quote from Harry Potter and the Sorcerer's Stone"
        system_prompt = " Convert this question to a meaning prompt for imagen model to create a good image"

        prompt = question + " " + system_prompt
        image_prompt = generate_pro(prompt)

        
        try:
            # Code that may break
            response = imagen_model.generate_images( prompt=image_prompt,)
            response.images[0].show()
        
        except Exception as e:
            # Handle the exception
            print(f"An error occurred: {e}")
            print("skipping to next question - no image for this")

    prev_question = question
# Out:
# What is a quote from Harry Potter and the Sorcerer's Stone?
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 25
#      22 system_prompt = " Convert this question to a meaning prompt for imagen model to create a good image"
#      24 prompt = question + " " + system_prompt
# ---> 25 image_prompt = generate_pro(prompt)
#      28 try:
#      29     # Code that may break
#      30     response = imagen_model.generate_images( prompt=image_prompt,)
#
# Cell In[56], line 23, in generate_pro(input_prompt)
#      20 all_response  = []
#      22 for response in responses:
# ---> 23     all_response.append(response.text)
#      25 # print (all_response)
#      27 return(" ".join(all_response))
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:1315, in GenerationResponse.text(self)
#    1313 if len(self.candidates) > 1:
#    1314     raise ValueError("Multiple candidates are not supported")
# -> 1315 return self.candidates[0].text
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:1368, in Candidate.text(self)
#    1366 @property
#    1367 def text(self) -> str:
# -> 1368     return self.content.text
#
# File ~/.local/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:1425, in Content.text(self)
#    1423     raise ValueError("Multiple content parts are not supported.")
#    1424 if not self.parts:
# -> 1425     raise ValueError("Content has no parts.")
#    1426 return self.parts[0].text
#
# ValueError: Content has no parts.
