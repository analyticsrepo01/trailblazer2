# %% [markdown]
# #### This Notebook use matching engine along with Gemini Models
#
# #### Author: Saurabh Mangal (saurabhmangal@google.com)
# ##### Date: 21st Feb
# ##### Description: This notebook contains part 4 of lab
#
#  Copyright (c) [2024] [saurabhmangal@] --
#  This notebook is licensed under the Commercial License.

# %% [markdown]
# ### Installation of required libs for Gemini and PaLM

# %%
# !pip install streamlit

# %%
# !pip install --upgrade google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/envs/pytorch/lib/python3.10/site-packages (1.42.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.17.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.61.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.25.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2023.7.22)

# %%
# !pip install --upgrade google-cloud-aiplatform
GCP_PROJECT= PROJECT_ID=project_id='my-project-0004-346516'
LOCATION = REGION = 'us-central1'
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/envs/pytorch/lib/python3.10/site-packages (1.42.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.17.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.20.3)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (23.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.14.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.61.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.25.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform) (0.5.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/pytorch/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform) (2023.7.22)

# %% [markdown]
# ### Vertex AI setup

# %%
### Defining PaLM Functions

# %%
import os

# import streamlit as st
import vertexai
from vertexai.preview.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)


# @st.cache_resource
def get_model():
    generation_model = TextGenerationModel.from_pretrained("text-bison@002")
    return generation_model


def get_text_generation(prompt="", **parameters):
    generation_model = get_model()
    response = generation_model.predict(prompt=prompt, **parameters)

    return response.text

# %% [markdown]
# ### Defining Gemini Functions

# %%
import vertexai
from vertexai.preview.generative_models import GenerativeModel, Part

# input_prompt = """can you give me details of paracetamol"""

def generate(input_prompt):
    model = GenerativeModel("gemini-ultra")
    responses = model.generate_content(
        input_prompt ,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1,
        "top_k": 32
    },
        safety_settings=[],
        stream=True,
    )
    
    all_response  = []
    
    for response in responses:
        # print(response.text, end="")
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))
    

def generate_pro(input_prompt):
    model = GenerativeModel("gemini-pro")
    responses = model.generate_content(
    input_prompt,
    generation_config={
        "max_output_tokens": 2048,
        "temperature": 0.2,
        "top_p": 1
    },stream=True,)
    
    all_response  = []
    
    for response in responses:
        all_response.append(response.text)
    
    # print (all_response)
    
    return(" ".join(all_response))

from langchain_google_vertexai import VertexAI as langchainVertexAI

def generate_langchain_pro(input_prompt):
    model = langchainVertexAI(model_name="gemini-pro")

    all_response = model.invoke(input_prompt)

    # print (all_response)
    
    return(all_response)

# %%
import vertexai
from vertexai.language_models import TextGenerationModel

vertexai.init(project=PROJECT_ID, location=LOCATION)
parameters = {
    "candidate_count": 1,
    "max_output_tokens": 1024,
    "temperature": 1,
    "top_k": 40
}

def generate_palm_unicorn_v1(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-unicorn@001")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

def generate_palm_bison32k(input_prompt):
    
    model = TextGenerationModel.from_pretrained("text-bison-32k")

    response = model.predict(
        input_prompt,
        **parameters
    )
    print(f"Response from Model: {response.text}")
    
    return(response.text)

# %% [markdown]
# ### Read the Q&A file

# %% [markdown]
# #### This uses the file from Matching Engine which has questions and retrieved document results

# %%
import pandas as pd
filename = "./harry_potte_qa_output.csv"
df_qa = pd.read_csv(filename, sep ="|")

# print(df_qa.head(1))
System_Prompts = """ You are an expert in reading harry potter books, but only provide evidences from the information provide and do not use an other information
so here are some search results : 
"""

Question_Prompts = """ -- Based on information above help to answer following user question
"""

df_qa['combine_prompt_RAG1'] = System_Prompts + ' ' +df_qa['pagewise_texts_v1'] + ' Please answers the Question : '+ df_qa['Question'] 
df_qa['combine_prompt_RAG2'] = System_Prompts + ' ' +df_qa['pagewise_texts_v2'] + ' Please answers the Questio : '+ df_qa['Question'] 
df_qa['combine_prompt_RAG3'] = System_Prompts + ' ' +df_qa['pagewise_texts_v3'] + ' Please answers the Question : '+ df_qa['Question'] 


# print(df['System Prompts'], df['RAG Results'] ,df['User Question'] )
# print(selected_column[0])

# %%
import re

# %%
for i in range(0, len(df_qa)):


    clean_text1 = re.sub(r'[^\w\s;]', '', df_qa.loc[i,'combine_prompt_RAG1'])
    clean_text2 = re.sub(r'[^\w\s;]', '', df_qa.loc[i,'combine_prompt_RAG2'])
    clean_text3 = re.sub(r'[^\w\s;]', '', df_qa.loc[i,'combine_prompt_RAG3'])

    if i<=1000:
        # df['Gemini_ultra_model_output'][i] = generate(df['combine_prompt'][i])
        print("iteration #", i, "test")
        if i==32 : 
            print("iteration #", i, "test", clean_text1, clean_text2, clean_text3)
    
    try:
        df_qa.loc[i, "Gemini_pro_model_output_v1"] = generate_pro(clean_text1)
        df_qa.loc[i, "Gemini_pro_model_output_v2"] = generate_pro(clean_text2)
        df_qa.loc[i, "Gemini_pro_model_output_v3"] = generate_pro(clean_text3)
        df_qa.loc[i, "Gemini_pro_model_output_v4"] = generate_langchain_pro(clean_text1)
        
        
    except :
        print("Prompt error at gemini ", i)
        df_qa.loc[i, "Gemini_pro_model_output_v1"] = "Prompt failed "
        df_qa.loc[i, "Gemini_pro_model_output_v2"] = "Prompt failed "
        df_qa.loc[i, "Gemini_pro_model_output_v3"] = "Prompt failed "
        df_qa.loc[i, "Gemini_pro_model_output_v4"] = "Prompt failed "
        

    try:
        df_qa.loc[i, "palm_bison32k_output_v1"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG1'])
        df_qa.loc[i, "palm_bison32k_output_v2"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG2'])
        df_qa.loc[i, "palm_bison32k_output_v3"] = generate_palm_bison32k(df_qa.loc[i,'combine_prompt_RAG3'])
    except ZeroDivisionError:
        print("Prompt error at palm ", i)
        df_qa.loc[i, "palm_bison32k_output_v1"] = "Prompt failed "
        df_qa.loc[i, "palm_bison32k_output_v2"] = "Prompt failed "
        df_qa.loc[i, "palm_bison32k_output_v3"] = "Prompt failed "
    

# generate_medllms_v1(input_prompt)
# generate_palm_unicorn_v1(input_prompt)
# input_prompt = "What are the symptoms of influenza?" 
# generate_medlpalm(input_prompt)    
    
# print( "/n output here ::" , df['Gemini_ultra_model_output'][i])
# df = df.assign(Gemini_ultra_model_output=generate(df.combine_prompt))
# df['combine_prompt'].head(3)

# df['Gemini_ultra_model_output'].head(3)
# Out:
# iteration # 0 test
# Response from Model:  The provided text does not contain information about a magical creature that can only be seen by those who have witnessed death.
# Response from Model:  The provided text does not mention any magical creature that can only be seen by those who have witnessed death.
# Response from Model:  The provided text does not mention any magical creature that can only be seen by those who have witnessed death.
# iteration # 1 test
# Response from Model:  The provided text does not mention the name of the school newspaper at Hogwarts.
# Response from Model:  The provided text does not mention the name of the school newspaper at Hogwarts.
# Response from Model:  The provided text does not specify the name of the school newspaper at Hogwarts.
# iteration # 2 test
# Response from Model:  The text does not contain the name of any magical map that shows the entire layout of Hogwarts.
# Response from Model:  The context provided does not mention anything about the name of the magical map that shows the entire layout of Hogwarts, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about a magical map that shows the entire layout of Hogwarts.
# iteration # 3 test
# Response from Model:  The provided text does not mention Luna Lovegood or which Hogwarts house she belongs to.
# Response from Model:  The provided text does not mention Luna Lovegood or any Hogwarts house she belongs to.
# Response from Model:  The Hogwarts house Luna Lovegood belongs to is not found in the provided text.
# iteration # 4 test
# Response from Model:  The provided text doesn't mention any magical creature guarding Gringott's Bank.
# Response from Model:  The provided text does not mention any magical creature guarding Gringott's Bank.
# Response from Model:  The provided text does not mention any magical creature guarding Gringott's Bank.
# iteration # 5 test
# Response from Model:  The provided text doesn't mention Polyjuice Potion or its ingredients, so I can't answer that question.
# Response from Model:  The provided text does not mention the primary ingredient in Polyjuice potion.
# Response from Model:  The provided text does not specify the primary ingredient in Polyjuice potion, so I cannot answer this question from the provided context.
# iteration # 6 test
# Response from Model:  The provided text doesn't mention the name of the three-headed dog guarding the trapdoor in Harry Potter and the Sorcerer's Stone.
# Response from Model:  The information provided does not mention the name of the three-headed dog guarding the trapdoor in Harry Potter and the Sorcerer's Stone.
# Response from Model:  This context does not mention anything about the name of the three-headed dog guarding the trapdoor in Harry Potter and the Sorcerer's Stone, so I cannot answer this question from the provided context.
# iteration # 7 test
# Response from Model:  The provided text does not contain any information about what position Harry plays in Quidditch.
# Response from Model:  The provided text does not mention Harry Potter's position in Quidditch.
# Response from Model:  The provided text does not contain any information about Quidditch or Harry's position in the sport.
# iteration # 8 test
# Response from Model:  The provided text does not contain any information about Hermione holding the first meeting for students interested in joining Dumbledore's Army.
# Response from Model:  The provided text doesn't mention Hermione holding any meetings for students interested in joining Dumbledore's Army.
# Response from Model:  The provided text does not mention Hermione or Dumbledore's Army, so I cannot answer this question from the provided information.
# iteration # 9 test
# Response from Model:  The provided text does not mention Hermione's cat or its name, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Hermione's cat's name.
# Response from Model:  The information provided in the text does not mention the name of Hermione's cat, therefore I cannot answer the question.
# iteration # 10 test
# Response from Model:  The information provided doesn't mention which pub in London conceals the entrance to Diagon Alley.
# Response from Model:  The provided text does not mention any pub in London that conceals the entrance to Diagon Alley.
# Response from Model:  The given text does not mention any pub in London that conceals the entrance to Diagon Alley.
# iteration # 11 test
# Response from Model:  The provided text does not mention anything about Fred and George's eavesdropping tool in Harry Potter and the Order of the Phoenix. So I am unable to answer your question.
# Response from Model:  The provided text does not mention any eavesdropping tool invented by Fred and George in Harry Potter and the Order of the Phoenix.
# Response from Model:  The provided text does not contain information about the eavesdropping tool that Fred and George invented in Harry Potter and the Order of the Phoenix.
# iteration # 12 test
# Response from Model:  The provided text does not contain any information about the Slytherin ghost.
# Response from Model:  The provided text does not mention the name of the Slytherin ghost.
# Response from Model:  This context does not mention anything about the Slytherin ghost, so I cannot answer this question from the provided context.
# iteration # 13 test
# Response from Model:  The provided text does not contain any information about the names of Harry's children.
# Response from Model:  The provided text doesn't mention anything about Harry's children, so I cannot answer this question from the given context.
# Response from Model:  The provided text does not mention what Harry names his children, so I cannot answer this question from the provided information.
# iteration # 14 test
# Response from Model:  The provided text does not contain any information about bezoars.
# Response from Model:  The provided text does not mention bezoars or where to find them.
# Response from Model:  The provided text does not mention anything about a bezoar.
# iteration # 15 test
# Response from Model:  The provided text does not mention the name of Dudley's friend who goes to the zoo with the Dursleys and Harry.
# Response from Model:  The provided text does not mention Dudley having a friend who goes to the zoo with the Dursleys and Harry.
# Response from Model:  The provided text does not mention the name of Dudley's friend who goes to the zoo with the Dursleys and Harry. So I cannot answer this question.
# iteration # 16 test
# Response from Model:  The provided text does not specify what type of animal Harry accidentally set free at the zoo.
# Response from Model:  The provided text doesn't mention anything about Harry or a zoo, so I can't answer this question.
# Response from Model:  The provided text does not contain any information about Harry accidentally setting an animal free at the zoo.
# iteration # 17 test
# Response from Model:  This information is not provided in the given text.
# Response from Model:  The provided text does not mention the names of the couple that attends dinner at the Dursley's when Dobby shows up to stop Harry from returning to Hogwarts.
# Response from Model:  The provided text does not mention the name of the couple that attends dinner at the Dursleys when Dobby shows up to stop Harry from returning to Hogwarts.
# iteration # 18 test
# Response from Model:  The provided text does not mention anything about a boggart or Mrs. Weasley. So I cannot answer this question.
# Response from Model:  This context does not mention anything about what the boggart turns into when Mrs. Weasley sees it, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about a boggart or Mrs. Weasley.
# iteration # 19 test
# Response from Model:  This context does not mention anything about who finds Harry on the Hogwarts Express after Malfoy breaks his nose and leaves him under the Invisibility Cloak, so I cannot answer this question from the provided context.
# Response from Model:  This information cannot be found in the text provided.
# Response from Model:  This context does not mention anything about Harry Potter and the Half-Blood Prince, or about who finds Harry on the Hogwarts Express after Malfoy breaks his nose and leaves him under the Invisibility Cloak, so I cannot answer this question from the provided context.
# iteration # 20 test
# Response from Model:  The provided text does not provide information about Hermione Granger or her ability to take extra lessons.
# Response from Model:  The provided text does not mention how Hermione was able to take extra lessons, so I cannot answer this question from the provided context.
# Response from Model:  The information provided does not mention Hermione or any extra lessons.
# iteration # 21 test
# Response from Model:  The provided text does not contain any information about who is manipulated into vandalizing Hogwarts with messages about the Chamber of Secrets.
# Response from Model:  The provided text does not mention anyone being manipulated into vandalizing Hogwarts with messages about the Chamber of Secrets.
# Response from Model:  The provided text does not contain any information about who vandalized Hogwarts with messages about the Chamber of Secrets.
# iteration # 22 test
# Response from Model:  The provided text does not contain any information about Ron's fear of insects.
# Response from Model:  The provided text does not specify which insect Ron is afraid of.
# Response from Model:  The provided text does not mention any insect that Ron is afraid of.
# iteration # 23 test
# Response from Model:  The provided text does not mention Hagrid or his half-brother, so the question cannot be answered.
# Response from Model:  The provided text does not mention the name of Hagrid's half-brother.
# Response from Model:  The text you provided does not mention anything about Hagrid's half-brother's name.
# iteration # 24 test
# Response from Model:  The provided text does not mention anything about Hermione's patronus, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Hermione's patronus, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention anything about Hermione's patronus, so I cannot answer this question from the given context.
# iteration # 25 test
# Response from Model:  The provided text does not mention the Weasley twins' magic joke shop.
# Response from Model:  The provided text does not mention the name of the Weasley twins’ magic joke shop.
# Response from Model:  The provided text does not contain information about the name of the Weasley twins' magic joke shop.
# iteration # 26 test
# Response from Model:  The provided text does not specify where Harry Potter was born.
# Response from Model:  The provided text does not specify where Harry Potter was born.
# Response from Model:  The provided text does not mention where Harry Potter was born.
# iteration # 27 test
# Response from Model:  The provided text does not mention Professor McGonagall or her animagus form.
# Response from Model:  The provided text does not mention Professor McGonagall or her animagus.
# Response from Model:  The provided text does not contain any information about Professor McGonagall's animagus form.
# iteration # 28 test
# Response from Model:  The provided text does not mention the name of the Gryffindor ghost.
# Response from Model:  The provided text does not mention the name of the Gryffindor ghost, so I cannot answer this question.
# Response from Model:  The provided text does not contain information about the name of the Gryffindor ghost.
# iteration # 29 test
# Response from Model:  The text provided does not mention Fluffy.
# Response from Model:  The provided text does not specify what type of creature Fluffy is.
# Response from Model:  This text doesn't mention Fluffy, so I can't answer this question.
# iteration # 30 test
# Response from Model:  The provided text does not mention who Harry's godfather is, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not contain any information about Harry's godfather.
# Response from Model:  This information is not available in the provided text.
# iteration # 31 test
# Response from Model:  There is no mention of Voldemort's real name in the provided text.
# Response from Model:  The provided text does not mention Voldemort's real name.
# Response from Model:  According to the provided text, Voldemort's real name is Tom Marvolo Riddle.
# iteration # 32 test
# iteration # 32 test  You are an expert in reading harry potter books but only provide evidences from the information provide and do not use an other information
# so here are some search results
#  Professor McGonagalls voice trembled as she went on Thats not all
# Theyre saying he tried to kill the Potters son Harry But he couldnt He
# couldnt kill that little boy No one knows why or how but theyre saying that
# when he couldnt kill Harry Potter Voldemorts power somehow broke  and
# thats why hes gone
# Dumbledore nodded glumly
# Its  its true faltered Professor McGonagall After all hes done
# all the people hes killedhe couldnt kill a little boy Its just astoundingof
# all the things to stop himbut how in the name of heaven did Harry survive
# We can only guess said Dumbledore We may never know
# Professor McGonagall pulled out a lace handkerchief and dabbed at her
# eyes beneath her spectacles Dumbledore gave a great sniff as he took a golden
# watch from his pocket and examined it It was a very odd watch It had twelve
# hands but no numbers; instead little planets were moving around the edge It
# must have made sense to Dumbledore though because he put it back in his
# pocket and said Hagrids late I suppose it was he who told you Id be here by
# the way
# Yes said Professor McGonagall And I dont suppose youre going to
# tell me why youre here of all places
# Ive come to bring Harry to his aunt and uncle Theyre the only family
# he has left now
# You dont mean  you cant mean the people who live here cried
# Professor McGonagall jumping to her feet and pointing at number four
# Dumbledore  you cant Ive been watching them all day You couldnt find
# two people who are less like us And theyve got this son  I saw him kicking
# his mother all the way up the street screaming for sweets Harry Potter come
# and live here
# Its the best place for him said Dumbledore firmly His aunt and
# uncle will be able to explain everything to him when hes older Ive written
# them a letter
# A letter repeated Professor McGonagall faintly sitting back down on
# the wall Really Dumbledore you think you can explain all this in a letter
# These people will never understand him Hell be famous  a legend  I
# wouldnt be surprised if today was known as Harry Potter day in the future
# there will be books written about Harry  every child in our world will know
# his name
# Exactly said Dumbledore looking very seriously over the top of his
# halfmoon glasses It would be enough to turn any boys head Famous before
# he can walk and talk Famous for something he wont even remember Can you
#
#
#  Please answers the Question  What is the British term for a nonmagical person   You are an expert in reading harry potter books but only provide evidences from the information provide and do not use an other information
# so here are some search results
#  CHAPTER ONE
# THE BOY WHO LIVED
# M r and Mrs Dursley of number four Privet Drive were proud to say
# that they were perfectly normal thank you very much They were the last people
# youd expect to be involved in anything strange or mysterious because they just
# didnt hold with such nonsense
# Mr Dursley was the director of a firm called Grunnings which made
# drills He was a big beefy man with hardly any neck although he did have a
# very large mustache Mrs Dursley was thin and blonde and had nearly twice the
# usual amount of neck which came in very useful as she spent so much of her
# time craning over garden fences spying on the neighbors The Dursleys had a
# small
# son called Dudley and in their opinion there was no finer boy anywhere
# The Dursleys had everything they wanted but they also had a secret and
# their greatest fear was that somebody would discover it They didnt think they
# could bear it if anyone found out about the Potters Mrs Potter was Mrs
# Dursleys sister but they hadnt met for several years; in fact Mrs Dursley
# pretended she didnt have a sister because her sister and her goodfornothing
# husband were as unDursleyish as it was possible to be The Dursleys shuddered
# to think what the neighbors would say if the Potters arrived in the street The
# Dursleys knew that the Potters had a small son too but they had never even
# seen him This boy was another good reason for keeping the Potters away; they
# didnt want Dudley mixing with a child like that
# When Mr and Mrs Dursley woke up on the dull gray Tuesday our story
# starts there was nothing about the cloudy sky outside to suggest that strange and
# mysterious things would soon be happening all over the country Mr Dursley
# hummed as he picked out his most boring tie for work and Mrs Dursley
# gossiped away happily as she wrestled a screaming Dudley into his high chair
# None of them noticed a large tawny owl flutter past the window
# At half past eight Mr Dursley picked up his briefcase pecked Mrs
# Dursley on the cheek and tried to kiss Dudley goodbye but missed because
# Dudley was now having a tantrum and throwing his cereal at the walls
# Little tyke chortled Mr Dursley as he left the house He got into his car
# and backed out of number fours drive
# It was on the corner of the street that he noticed the first sign of
#  Please answers the Questio  What is the British term for a nonmagical person   You are an expert in reading harry potter books but only provide evidences from the information provide and do not use an other information
# so here are some search results
#  It certainly seems so said Dumbledore We have much to be thankful
# for Would
# you care for a lemon drop
# A what
# A lemon drop Theyre a kind of Muggle sweet Im rather fond of
# No thank you said Professor McGonagall coldly as though she didnt
# think this was the moment for lemon drops As I say even if YouKnowWho
# has gone
# My dear Professor surely a sensible person like yourself can call him by
# his name All this YouKnowWho nonsense  for eleven years I have been
# trying to persuade people to call him by his proper name Voldemort Professor
# McGonagall flinched but Dumbledore who was unsticking two lemon drops
# seemed not to notice It all gets so confusing if we keep saying YouKnow
# Who I have never seen any reason to be frightened of saying Voldemorts
# name
# I know you havent said Professor McGonagall sounding half
# exasperated half admiring But youre different Everyone knows youre the
# only one YouKnow oh all right Voldemort was frightened of
# You flatter me said Dumbledore calmly Voldemort had powers I will
# never have
# Only because youre too  well  noble to use them
# Its lucky its dark I havent blushed so much since Madam Pomfrey
# told me she liked my new earmuffs
# Professor McGonagall shot a sharp look at Dumbledore and said The
# owls are nothing next to the rumors that are flying around You know what
# theyre saying About why hes disappeared About what finally stopped him
# It seemed that Professor McGonagall had reached the point she was most
# anxious to discuss the real reason she had been waiting on a cold hard wall all
# day for neither as a cat nor as a woman had she fixed Dumbledore with such a
# piercing stare as she did now It was plain that whatever everyone was saying
# she was not going to believe it until Dumbledore told her it was true
# Dumbledore however was choosing another lemon drop and did not answer
# What theyre saying she pressed on is that last night Voldemort
# turned up in Godrics Hollow He went to find the Potters The rumor is that Lily
# and James Potter are  are  that theyre  dead
# Dumbledore bowed his head Professor McGonagall gasped
# Albus
# Lily and JamesI cant believe itI didnt want to believe itOh
# Dumbledore reached out and patted her on the shoulder I knowI
# know he said heavily
#  Please answers the Question  What is the British term for a nonmagical person
# Prompt error at gemini  32
# Response from Model:  The text does not mention the British term for a nonmagical person.
# Response from Model:  In the provided chapter of "Harry Potter and the Sorcerer's Stone," there is no mention of the specific British term for a nonmagical person.
# Response from Model:  Muggle
# iteration # 33 test
# Response from Model:  The answer is Draco Malfoy.
#
# The provided text does not mention which house Draco Malfoy is in. However, it does mention that Harry Potter, Ron Weasley, and Ginny Weasley are all in Gryffindor.
# Response from Model:  The provided text does not mention anything about who is in Gryffindor, so I cannot answer this question.
# Response from Model:  The information provided does not mention which house Draco Malfoy is in, so it is not possible to determine if he is in Gryffindor or not.
# iteration # 34 test
# Response from Model:  The provided text does not specify Harry's middle name.
# Response from Model:  The provided text does not mention Harry's middle name.
# Response from Model:  The provided text does not mention Harry's middle name.
# iteration # 35 test
# Response from Model:  The provided text does not mention what year Hogwarts students take O.W.L.s.
# Response from Model:  The context you provided does not mention the year in which Hogwarts students take O.W.L.s, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not specify the year in which Hogwarts students take O.W.L.s.
# iteration # 36 test
# Response from Model:  This context does not mention anything about Harry getting a Firebolt or who sent it to him, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention who sent Harry his Firebolt.
# Response from Model:  The provided text does not specify who sent Harry the Firebolt.
# iteration # 37 test
# Response from Model:  There is no information about which Weasley dies during the final battle of Hogwarts in the provided text.
# Response from Model:  The provided text does not contain the answer to this question.
# Response from Model:  The provided text does not mention any Weasley dying during the final battle of Hogwarts.
# iteration # 38 test
# Response from Model:  The provided text does not contain any information about Xenophilius Lovegood or the magazine he publishes.
# Response from Model:  The text provided does not mention anything about Xenophilius Lovegood or the magazine he publishes, so I cannot answer this question from the provided information.
# Response from Model:  The provided information does not mention Xenophilius Lovegood or any magazine that he publishes.
# iteration # 39 test
# Response from Model:  The provided text does not mention any incantations that can levitate an object.
# Response from Model:  There is no mention of an incantation that can levitate an object in the provided text.
# Response from Model:  The provided text does not mention any incantations for levitating objects.
# iteration # 40 test
# Response from Model:  The provided text does not mention anything about Harry or Hogwarts, so I cannot answer this question.
# Response from Model:  The provided text doesn't mention any information about what Harry did to get him temporarily expelled from Hogwarts.
# Response from Model:  The provided text does not contain information about Harry getting temporarily expelled from Hogwarts.
# iteration # 41 test
# Response from Model:  The provided text does not contain any information about the Black family home address.
# Response from Model:  The provided text does not mention the address of the Black family home.
# Response from Model:  The provided text does not mention the Black family home address.
# iteration # 42 test
# Response from Model:  The provided text does not specify Harry's birthday.
# Response from Model:  The provided text does not mention Harry Potter's birthday.
# Response from Model:  The provided text does not specify Harry Potter's birthday.
# iteration # 43 test
# Response from Model:  The provided text does not specify the birth order of the Weasley children.
# Response from Model:  The provided text does not mention the Weasley children or their birth order, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain any information about the birth order of the Weasley children.
# iteration # 44 test
# Response from Model:  The text you provided does not mention who anonymously sends Harry his father's Invisibility Cloak on Christmas.
# Response from Model:  The provided text does not mention who anonymously sends Harry his father's Invisibility Cloak on Christmas.
# Response from Model:  The provided text does not mention who sends Harry his father's Invisibility Cloak on Christmas.
# iteration # 45 test
# Response from Model:  The provided text does not mention the animal symbol of Ravenclaw.
# Response from Model:  The text provided does not contain any information about the animal symbol of Ravenclaw.
# Response from Model:  The provided text does not mention the animal symbol of Ravenclaw.
# iteration # 46 test
# Response from Model:  The provided text does not mention Hagrid's boarhound dog's name, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Hagrid's boarhound dog's name, so I cannot answer this question.
# Response from Model:  The provided text does not mention the name of Hagrid's boarhound dog.
# iteration # 47 test
# Response from Model:  The provided text does not mention Harry Potter having a pet dragon.
# Response from Model:  The provided text does not mention anything about Mr. Dursley having a pet dragon.
# Response from Model:  There is no mention of a pet dragon in the provided text.
# iteration # 48 test
# Response from Model:  The provided text does not specify who betrayed Lily and James Potter.
# Response from Model:  The provided text does not mention who betrayed Lily and James Potter.
# Response from Model:  The information provided does not state who betrays Lily and James Potter.
# iteration # 49 test
# Response from Model:  The provided text does not specify the name of the Weasley family home.
# Response from Model:  The provided text does not mention the name of the Weasley family home.
# Response from Model:  This context does not mention anything about the name of the Weasley family home, so I cannot answer this question from the provided context.
# iteration # 50 test
# Response from Model:  The provided text does not mention any potion that gives good luck to those who drink it.
# Response from Model:  The provided text does not mention any potion that gives good luck to those who drink it.
# Response from Model:  The provided text does not contain any information about a potion that gives good luck to those who drink it.
# iteration # 51 test
# Response from Model:  The provided text does not specify the maiden name of Lily Potter and Petunia Dursley.
# Response from Model:  The provided text does not specify the maiden name of Lily Potter and Petunia Dursley.
# Response from Model:  The provided text does not mention the maiden name of Lily Potter and Petunia Dursley, so I cannot answer this question.
# iteration # 52 test
# Response from Model:  The provided text does not mention anything about which Hogwarts house Lavender Brown, Pansy Parkinson, Blaise Zabini, or Greggory Goyle belong to, so I cannot answer this question.
# Response from Model:  The provided text does not contain any information about the Harry Potter characters Lavender Brown, Pansy Parkinson, Blaise Zabini, or Greggory Goyle, or which house they belong to. So I cannot answer this question.
# Response from Model:  The provided text does not specify which Hogwarts house Lavender Brown, Pansy Parkinson, Blaise Zabini, or Greggory Goyle belong to. So I cannot answer this question from the provided context.
# iteration # 53 test
# Response from Model:  The provided text does not specify the exact day on which James and Lily Potter died.
# Response from Model:  Unfortunately, the text does not specify the exact day that James and Lily Potter died.
# Response from Model:  The provided text does not specify the day that James and Lily Potter died.
# iteration # 54 test
# Response from Model:  The provided text doesn't mention anything about Professor McGonagall or the classes she teaches, so I can't answer this question from the provided context.
# Response from Model:  This text does not mention what class Professor McGonagall teaches.
# Response from Model:  The provided text does not contain information about Professor McGonagall or the classes she teaches.
# iteration # 55 test
# Response from Model:  The provided information does not contain details about who Bill Weasley marries.
# Response from Model:  The provided text does not mention Bill Weasley or who he marries.
# Response from Model:  The provided text does not mention who Bill Weasley marries.
# iteration # 56 test
# Response from Model:  The provided text does not specify what kind of wood Harry's first wand is made out of.
# Response from Model:  The provided text does not mention what kind of wood Harry's first wand is made out of.
# Response from Model:  The provided text does not specify the type of wood used to make Harry's first wand.
# iteration # 57 test
# Response from Model:  The provided text does not mention Horcruxes or how many Voldemort created intentionally.
# Response from Model:  The information you've provided does not contain any details about the Horcruxes or their creation.
# Response from Model:  The provided text does not mention Horcruxes or provide any information about them.
# iteration # 58 test
# Response from Model:  The provided text does not mention anything about who wrote "A History of Magic."
# Response from Model:  The provided text does not specify who wrote A History of Magic.
# Response from Model:  The provided text does not specify who wrote A History of Magic.
# iteration # 59 test
# Response from Model:  The provided text does not mention who kills Dobby.
# Response from Model:  The provided text does not mention anything about Dobby's death or who kills him.
# Response from Model:  This article does not mention anything about who kills Dobby, so I cannot answer this question.
# iteration # 60 test
# Response from Model:  The provided text does not mention Justin Finch-Fletchley's house.
# Response from Model:  The provided text does not contain any information about Justin Finch-Fletchley or the house he belongs to.
# Response from Model:  The provided text does not contain any information about Justin Finch-Fletchley's house.
# iteration # 61 test
# Response from Model:  The provided text does not mention Hagrid's wand being broken or what he uses to channel the pieces.
# Response from Model:  The provided text does not mention Hagrid's wand being broken or how he channels the pieces of his wand.
# Response from Model:  This context does not mention anything about Hagrid's wand, so I cannot answer this question from the provided context.
# iteration # 62 test
# Response from Model:  The provided text does not mention Quidditch or the number of players on a Quidditch team.
# Response from Model:  The provided text does not contain any information about the number of players on a Quidditch team.
# Response from Model:  The provided text does not contain any information about Quidditch or the number of players on a Quidditch team.
# iteration # 63 test
# Response from Model:  The information provided does not contain the answer to the question as to what children's book contains the story of the Deathly Hallows.
# Response from Model:  The provided text does not specify the name of any children's book that contains the story of the Deathly Hallows, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the Deathly Hallows or any children's book containing their story.
# iteration # 64 test
# Response from Model:  The provided text does not contain any information about the Chamber of Secrets or its entrance.
# Response from Model:  The provided text does not specify where the entrance to the Chamber of Secrets is hidden.
# Response from Model:  The provided text does not mention anything about the entrance to the Chamber of Secrets.
# iteration # 65 test
# Response from Model:  The provided text does not mention anything about teleportation magic that sixth-years learn at Hogwarts.
# Response from Model:  The provided text does not mention any sixth-year teleportation magic taught at Hogwarts.
# Response from Model:  The provided text does not mention anything about teleportation magic that sixth-years learn at Hogwarts.
# iteration # 66 test
# Response from Model:  The provided text does not contain any information about Aragog, therefore, I am unable to answer your question.
# Response from Model:  The provided text does not mention Aragog or any other magical creatures, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Aragog or what kind of magical creature it is.
# iteration # 67 test
# Response from Model:  The provided text does not mention Ron's favorite Quidditch team, so I cannot answer this question from the given context.
# Response from Model:  The provided text does not mention Ron's favorite Quidditch team, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not contain any information about Ron's favorite Quidditch team.
# iteration # 68 test
# Response from Model:  The provided text does not specify Neville's birthday.
# Response from Model:  The provided text does not contain any information about Neville's birthday.
# Response from Model:  The provided text doesn't mention Neville's birthday.
# iteration # 69 test
# Response from Model:  The provided text does not mention James Potter's Marauder nickname.
# Response from Model:  The provided text does not contain the answer to what James Potter's Marauder nickname is.
# Response from Model:  The provided information doesn't specify James Potter's Marauder nickname.
# iteration # 70 test
# Response from Model:  The provided information does not mention anything about the Grey Lady or her relation to Rowena Ravenclaw.
# Response from Model:  The provided text does not mention the Grey Lady or her relation to Rowena Ravenclaw.
# Response from Model:  The provided text does not contain any information about the Grey Lady or her relationship to Rowena Ravenclaw.
# iteration # 71 test
# Response from Model:  The provided text does not mention Charlie Weasley or what he does for a living after graduation.
# Response from Model:  The provided text does not specify what Charlie Weasley does for a living after graduation.
# Response from Model:  The provided text does not mention anything about Charlie Weasley's occupation after graduation, so I cannot answer this question from the provided information.
# iteration # 72 test
# Response from Model:  The provided text does not mention the name Buckbeak or any information about it being saved from execution.
# Response from Model:  This text does not mention Buckbeak or provide any details about his execution or subsequent naming.
# Response from Model:  The text provided does not have any information about Buckbeak or his execution.
# iteration # 73 test
# Response from Model:  The provided text does not mention Dean Thomas or his favorite sport.
# Response from Model:  The provided text does not mention Dean Thomas or his favorite sport.
# Response from Model:  The provided information does not mention Dean Thomas or his favorite sport, so I cannot answer this question.
# iteration # 74 test
# Response from Model:  The provided text does not mention Harry Potter's winnings from the Triwizard Tournament or what he does with them. So I cannot answer this question.
# Response from Model:  The provided text does not contain any information about what Harry does with his winnings from the Triwizard Tournament.
# Response from Model:  The provided text does not mention anything about Harry's winnings from the Triwizard Tournament.
# iteration # 75 test
# Response from Model:  This context does not mention anything about Voldemort's mother's name, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Voldemort's mother's name, so I cannot answer this question from the provided information.
# Response from Model:  The provided text does not mention Voldemort's mother's name, so I cannot answer this question.
# iteration # 76 test
# Response from Model:  This context does not mention anything about the Gryffindor Quidditch team or its players, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the names of the Chasers on the Gryffindor Quidditch team when Harry joins.
# Response from Model:  The provided text does not mention the names of the Chasers on the Gryffindor Quidditch team when Harry joins.
# iteration # 77 test
# Response from Model:  The text does not mention who the first person to successfully break into Gringotts is.
# Response from Model:  The provided text does not mention who is the first person to ever successfully break into Gringotts.
# Response from Model:  The provided text does not mention who the first person to ever successfully break into Gringotts is, so I cannot answer this question from the provided information.
# iteration # 78 test
# Response from Model:  The provided text does not mention Bellatrix or Tonks, so I cannot answer this question from the provided text.
# Response from Model:  The text you provided does not contain any information about how Bellatrix is related to Tonks.
# Response from Model:  The provided text does not mention Bellatrix or Tonks, so I cannot answer this question.
# iteration # 79 test
# Response from Model:  The provided text does not mention Winky the house-elf or the family she belonged to before working at Hogwarts.
# Response from Model:  The provided text does not mention Winky the house-elf or the family she belonged to before working at Hogwarts.
# Response from Model:  The provided text does not contain any information about Winky the house-elf or the family she belonged to before working at Hogwarts.
# iteration # 80 test
# Response from Model:  The provided text does not mention the full name of Nearly Headless Nick.
# Response from Model:  The provided text does not contain the answer to this question.
# Response from Model:  This context does not mention anything about Nearly Headless Nick's full name, so I cannot answer this question from the provided context.
# iteration # 81 test
# Response from Model:  The provided text does not mention the Sorcerer's Stone co-creator Nicolas Flamel or his age. So I can not answer this question
# Response from Model:  The text provided does not mention the Sorcerer's Stone co-creator Nicolas Flamel's age when he decided to destroy it.
# Response from Model:  This context does not mention anything about the Sorcerer's Stone co-creator Nicolas Flamel's age when he decided to destroy it, so I cannot answer this question from the provided context.
# iteration # 82 test
# Response from Model:  The provided text does not mention Monkshood or Wolfsbane being the same plant.
# Response from Model:  The provided text does not contain the answer to your question.
# Response from Model:  The provided text does not mention Monkshood and wolfsbane being the same plant, or having another name.
# iteration # 83 test
# Response from Model:  The text provided does not specify the number of staircases that Hogwarts has, so I cannot answer this question from the provided text.
# Response from Model:  The provided information does not mention the number of staircases in Hogwarts.
# Response from Model:  This question can not be answered as the provided text does not contain the information.
# iteration # 84 test
# Response from Model:  The paragraph you have given does not contain any information about the rows of glowing orbs in the Hall of Prophecy or which row contains the prophecy about Harry and Voldemort. So, I cannot answer this question from the provided context.
# Response from Model:  The text you provided does not mention anything about the Hall of Prophecy, rows of glowing orbs, or a prophecy about Harry and Voldemort.
# Response from Model:  The provided text does not mention the Hall of Prophecy or any rows of glowing orbs, so I cannot answer this question.
# iteration # 85 test
# Response from Model:  The text you provided does not mention Quidditch or Quidditch fouls.
# Response from Model:  The provided text does not mention Quidditch or any possible fouls.
# Response from Model:  The provided text does not have information about Quidditch fouls, so I cannot answer this question.
# iteration # 86 test
# Response from Model:  This context does not mention anything about Dumbledore's scar, so I cannot answer this question from the provided context.
# Response from Model:  There is no evidence in the provided text that Albus Dumbledore has a scar above his left knee that is a perfect map of anything.
# Response from Model:  This context does not mention anything about Dumbledore having a scar above his left knee or what it could be a map of, so I cannot answer this question from the provided context.
# iteration # 87 test
# Prompt error at gemini  87
# Response from Model:  This text does not contain the answer to this question.
# Response from Model:  The provided text doesn't mention anything about Harry's 17th birthday or Hermione turning the leaves of the Weasleys’ crabapple tree.
# Response from Model:  The text you provided does not contain any information about Harry's 17th birthday or Hermione turning the leaves of the Weasleys' crabapple tree. So I cannot answer this question.
# iteration # 88 test
# Response from Model:  This question cannot be answered because the information provided does not include any details about the man's statue next to the lavatory entrance in The Goblet of Fire.
# Response from Model:  The provided text does not mention Cedric Diggory, the prefect's bathroom, or a statue of a man next to the lavatory entrance.
# Response from Model:  The provided text does not mention Cedric Diggory letting Harry use the prefect's bathroom in The Goblet of Fire. Additionally, it doesn't mention a statue of a man next to the lavatory entrance. So I cannot answer this question from the provided context.
# iteration # 89 test
# Response from Model:  This information is not available in the text provided.
# Response from Model:  The provided text does not mention Crookshanks or how Hermione, Harry, and Ron find him in Harry Potter and the Prisoner of Azkaban.
# Response from Model:  The information you provided does not contain any information about Harry Potter and the Prisoner of Azkaban or how Hermione, Harry, and Ron find Crookshanks.
# iteration # 90 test
# Response from Model:  The provided text does not mention anything about the max speed of a Firebolt broomstick.
# Response from Model:  The provided text does not specify the max speed of a Firebolt broomstick.
# Response from Model:  The text you have provided does not contain any information about the speed of a Firebolt broomstick, so I am unable to answer your question from the provided context.
# iteration # 91 test
# Response from Model:  The provided text does not contain information about the Quidditch World Cup or the Irish team's chasers.
# Response from Model:  The provided text does not contain any information about the Quidditch World Cup, Ireland's team, or a match where the first goal was scored.
# Response from Model:  The provided text does not contain any information about the Quidditch World Cup or the Irish team's chasers.
# iteration # 92 test
# Response from Model:  The provided text does not mention anything about Voldemort stealing Helga Hufflepuff's cup from an old woman named Hepzibah Smith, nor does it mention the name of her house-elf.
# Response from Model:  The provided text does not contain any information about Voldemort stealing Helga Hufflepuff's cup or an old woman named Hepzibah Smith, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Voldemort stealing Helga Hufflepuff's cup from an old woman named Hepzibah Smith, nor does it provide any information about a house-elf.
# iteration # 93 test
# Response from Model:  The provided text does not mention Ginny Weasley buying a Pygmy Puff or naming it.
# Response from Model:  The text you provided does not mention anything about Ginny Weasley buying a pet Pygmy Puff from her older brothers' joke shop or what she named it.
# Response from Model:  The provided text does not mention Ginny Weasley buying a pet Pygmy Puff or naming it.
# iteration # 94 test
# Response from Model:  The provided text does not mention anything about the Grey Lady or who killed her, so I cannot answer this question.
# Response from Model:  The provided text does not mention the Grey Lady or who killed her.
# Response from Model:  The provided text does not mention who killed the Grey Lady.
# iteration # 95 test
# Response from Model:  The text you provided does not mention Mrs. Weasley trying to give Harry a sock with a Quidditch team's name on it.
# Response from Model:  The name of the Quidditch team on the sock Mrs. Weasley tries to give to Harry is not mentioned in the text provided.
# Response from Model:  The provided text does not mention anything about a Quidditch team on a sock that Mrs. Weasley tries to give to Harry.
# iteration # 96 test
# Response from Model:  The provided text does not contain any information about Teddy Lupin's hair color when he was born.
# Response from Model:  The provided text does not specify the color of Teddy Lupin's hair when he is born.
# Response from Model:  The provided text does not mention the color of Teddy Lupin's hair when he is born.
# iteration # 97 test
# Response from Model:  The provided text does not mention Hermione Granger's preferences or attractions, so the requested information cannot be found in the text provided.
# Response from Model:  The provided text does not mention any specific scent that attracts Hermione Granger.
# Response from Model:  This context does not mention anything about what scent attracts Hermione Granger, so I cannot answer this question from the provided context.
# iteration # 98 test
# Response from Model:  The provided text does not mention Gilderoy Lockhart or the Witch Weekly's Most Charming Smile Award, so I cannot answer this question.
# Response from Model:  The paragraph you provided does not mention Gilderoy Lockhart or the Witch Weekly's Most Charming Smile Award. Therefore, I cannot answer this question.
# Response from Model:  The provided text does not contain any information about Gilderoy Lockhart winning Witch Weekly's Most Charming Smile Award.
# iteration # 99 test
# Response from Model:  The provided text does not contain any information about the core of Draco Malfoy's wand.
# Response from Model:  The provided text does not specify the core of Draco Malfoy's wand.
# Response from Model:  The provided text does not specify the core of Draco Malfoy's wand.
# iteration # 100 test
# Response from Model:  The provided text does not mention the name of the matron of the orphanage where Voldemort grows up.
# Response from Model:  The provided text does not mention an orphanage or provide any information about where Voldemort grows up. So I cannot answer this question from the provided text.
# Response from Model:  The provided text does not mention the matron of the orphanage where Voldemort grows up, so I cannot answer this question.
# iteration # 101 test
# ...
# iteration # 128 test
# Response from Model:  The provided text does not specify the color of Crookshanks's fur.
# Response from Model:  The provided text does not mention the color of Crookshanks's fur, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the color of Crookshanks's fur, so I cannot answer this question from the provided information.
# iteration # 129 test
# Response from Model:  The provided text does not contain any information about Nicolas Flamel's wife.
# Response from Model:  The provided text does not mention Nicolas Flamel or his wife.
# Response from Model:  The provided text does not mention Nicolas Flamel or his wife, so I cannot answer this question.
# iteration # 130 test
# Response from Model:  The provided text does not mention anything about Quidditch or the balls used in the game, so I cannot answer this question from the given context.
# Response from Model:  The provided text does not mention anything about Quidditch or the balls used in the sport. So I cannot answer this question.
# Response from Model:  The provided text does not mention anything about Quidditch or the balls used in the sport. So I cannot answer this question from the provided context.
# iteration # 131 test
# Response from Model:  The provided text does not specify Dumbledore's favorite flavor of jam.
# Response from Model:  The provided text does not mention Dumbledore's favorite flavor of jam.
# Response from Model:  The provided text does not specify Dumbledore's favorite flavor of jam.
# iteration # 132 test
# Response from Model:  The information provided does not contain any details about Professor Trelawney's first name.
# Response from Model:  The provided text does not specify Professor Trelawney's first name, so I cannot answer this question from the provided context.
# Response from Model:  This text does not mention Professor Trelawney's name, so I cannot answer this question from the provided context.
# iteration # 133 test
# Response from Model:  The provided text does not contain information about the number of Knuts in a Sickle.
# Response from Model:  The information provided does not mention the number of Knuts in a Sickle.
# Response from Model:  The provided text does not mention the number of Knuts in a Sickle.
# iteration # 134 test
# Response from Model:  The provided text does not mention the Department of Mysteries or its employees.
# Response from Model:  The provided text does not mention any employees of the Department of Mysteries.
# Response from Model:  The provided text does not provide any information about the employees of the Department of Mysteries.
# iteration # 135 test
# Response from Model:  The provided text does not contain any information about Bill and Fleur's children, so I cannot answer this question.
# Response from Model:  The provided text does not mention Bill and Fleur or their children.
# Response from Model:  The provided text does not mention Bill and Fleur's eldest child, so I cannot answer this question.
# iteration # 136 test
# Response from Model:  The provided text does not mention Dumbledore's middle name.
# Response from Model:  This passage does not provide Dumbledore's middle name.
# Response from Model:  The provided text does not specify Dumbledore's middle name.
# iteration # 137 test
# Response from Model:  The provided text does not mention anything about a Christmas event held to celebrate the Triwizard Tournament.
# Response from Model:  The provided text does not contain information about a Christmas event held to celebrate the Triwizard Tournament.
# Response from Model:  The provided text does not mention any Christmas event or the Triwizard Tournament.
# iteration # 138 test
# Response from Model:  The provided text does not mention Hannah Abbott or which house she is sorted into.
# Response from Model:  The provided text does not mention Hannah Abbott or the house she is sorted into.
# Response from Model:  The provided text does not mention Hannah Abbott's house.
# iteration # 139 test
# Response from Model:  This context does not mention anything about Harry Potter and the Prisoner of Azkaban, so I cannot answer this question from the provided context.
# Response from Model:  This information is not mentioned in the text.
# Response from Model:  The provided text does not mention anything about Harry Potter and the Prisoner of Azkaban, or about Harry getting on the Knight Bus and giving Stan a name. So I cannot answer this question.
# iteration # 140 test
# Response from Model:  This information is not provided in the text.
# Response from Model:  The provided text does not mention anything about the mascot that the Bulgarians bring to the Quidditch World Cup.
# Response from Model:  The provided text does not mention anything about the mascot the Bulgarians bring to the Quidditch World Cup.
# iteration # 141 test
# Response from Model:  The provided text does not mention anything about S.P.E.W., so I cannot answer this question.
# Response from Model:  The provided text does not contain information about S.P.E.W.
# Response from Model:  This context does not mention anything about S.P.E.W., so I cannot answer this question from the provided context.
# iteration # 142 test
# Response from Model:  There is no information about what happened to Neville's parents in the provided text.
# Response from Model:  The provided text does not mention anything about what happened to Neville's parents.
# Response from Model:  The provided text does not mention Neville's parents or what happened to them.
# iteration # 143 test
# Response from Model:  The text provided does not mention anything about the third task in Harry Potter and the Goblet of Fire or the sphinx's riddle.
# Response from Model:  The provided text does not contain any information about the third task in Harry Potter and the Goblet of Fire or the sphinx's riddle.
# Response from Model:  The context does not mention the third task in Harry Potter and the Goblet of Fire or the answer to the sphinx's riddle.
# iteration # 144 test
# Response from Model:  The provided text does not contain any information about Rita Skeeter listening to private conversations at Hogwarts.
# Response from Model:  The provided text does not mention Rita Skeeter or any instances of her listening to private conversations at Hogwarts.
# Response from Model:  There is no evidence in the given text that Rita Skeeter was listening to private conversations at Hogwarts all year.
# iteration # 145 test
# Response from Model:  The provided text does not mention anything about a Howler that Aunt Petunia receives.
# Response from Model:  This text does not include any information about a Howler being received by Aunt Petunia.
# Response from Model:  The provided text does not mention anything about Aunt Petunia receiving a Howler.
# iteration # 146 test
# Response from Model:  The provided text does not contain any information about who tells Harry about the Room of Requirement.
# Response from Model:  This context does not mention anything about who tells Harry about the Room of Requirement, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention the Room of Requirement or who tells Harry about it.
# iteration # 147 test
# Response from Model:  The provided text does not mention anything about Harry Potter and the Goblet of Fire or the name of the Muggle whom Voldemort kills inside the Riddle House.
# Response from Model:  The provided text does not contain information about the name of the Muggle whom Voldemort kills inside the Riddle House in Harry Potter and the Goblet of Fire.
# Response from Model:  The provided text does not contain the answer to the question, as it focuses on the events surrounding Harry Potter's infancy and does not mention the events in Harry Potter and the Goblet of Fire.
# iteration # 148 test
# Response from Model:  The context provided does not have information about the Harry, Ron, and Hermione communicating with the other members of Dumbledore's Army.
# Response from Model:  The provided text doesn't mention Harry, Ron, or Hermione, or Dumbledore's Army, so I can't answer this question.
# Response from Model:  This question is unanswerable from the provided context, as it does not mention how Harry, Ron, and Hermione communicated to the other members of Dumbledore's Army about their meetings.
# iteration # 149 test
# Response from Model:  The provided text does not have information about Neville or St. Mungo's.
# Response from Model:  This context does not mention anything about Neville being in St. Mungo's or receiving a gift from his mother, so I cannot answer this question from the provided context.
# Response from Model:  The context does not provide any information on Neville's time at St. Mungo's or the gift he receives from his mother.
# iteration # 150 test
# Response from Model:  The provided text does not mention the name of the centaur that replaces Trelawney as the professor of Divination.
# Response from Model:  The provided text does not mention the name of the centaur that replaces Trelawney as the professor of Divination.
# Response from Model:  The text provided does not mention anything about a centaur replacing Trelawney as the professor of Divination. So the answer is not available in the text provided.
# iteration # 151 test
# Response from Model:  The provided text does not contain information about the Order of the Phoenix moving out of 12 Grimmauld Place after Sirius's death.
# Response from Model:  The provided text does not mention anything about the Order of the Phoenix moving out of 12 Grimmauld Place after Sirius's death, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain information about why the Order of the Phoenix moves out of 12 Grimmauld Place after Sirius's death.
# iteration # 152 test
# Response from Model:  The provided text does not mention any nicknames given by Ginny to Fleur in Harry Potter and the Half-Blood Prince.
# Response from Model:  The provided text does not mention Ginny giving Fleur a nickname in Harry Potter and the Half-Blood Prince.
# Response from Model:  The provided text does not contain any information about Ginny giving Fleur a nickname in Harry Potter and the Half-Blood Prince.
# iteration # 153 test
# Response from Model:  There is no information provided about Ginny attending the Slug Club meeting on the Hogwarts Express in the given text.
# Response from Model:  The provided text does not mention Ginny attending the Slug Club meeting on the Hogwarts Express.
# Response from Model:  This context does not mention anything about Ginny Weasley or the Slug Club, so I cannot answer this question from the provided context.
# iteration # 154 test
# Response from Model:  The provided text does not mention Dumbledore's first visit with Tom Riddle or any interactions between them. Therefore, I cannot answer this question from the provided text.
# Response from Model:  There is no information about Dumbledore having Tom Riddle take something out of his wardrobe.
# Response from Model:  The provided text does not mention anything about Dumbledore's first visit with Tom Riddle, nor does it mention Dumbledore asking Tom to take anything out of his wardrobe at an orphanage.
# iteration # 155 test
# Response from Model:  This context does not mention anything about the "three D's" everyone must remember while learning to Apparate, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not contain information about Apparition or the "three D's" one must remember while learning to Apparate.
# Response from Model:  The provided text does not mention anything about the "three D's" or learning to Apparate.
# iteration # 156 test
# Response from Model:  The context provided does not mention Ron's cover story for not being at Hogwarts in Harry Potter and the Deathly Hallows, so I cannot answer this question.
# Response from Model:  The provided text does not mention Ron's cover story for not being at Hogwarts in Harry Potter and the Deathly Hallows.
# Response from Model:  The provided text does not mention Ron's cover story for not being at Hogwarts in Harry Potter and the Deathly Hallows.
# iteration # 157 test
# Response from Model:  This context does not mention anything about what fake name Harry uses while attending Bill and Fleur's wedding in disguise in Harry Potter and the Deathly Hallows, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention what fake name Harry uses while attending Bill and Fleur's wedding in disguise in Harry Potter and the Deathly Hallows.
# Response from Model:  There is no mention of the fake name used by Harry while attending Bill and Fleur's wedding in the provided text.
# iteration # 158 test
# Response from Model:  The text provided does not contain the answer to the question.
# Response from Model:  The provided text does not contain information about Harry breaking into the Ministry of Magic and stealing from Umbridge's office.
# Response from Model:  The provided text does not mention anything about Harry breaking into the Ministry of Magic or stealing anything from Umbridge's office in Harry Potter and the Deathly Hallows.
# iteration # 159 test
# Response from Model:  The provided text does not mention anything about the quote written on James and Lily's grave in Godric's Hollow.
# Response from Model:  The provided text does not contain any information about the quote written on James and Lily's grave in Godric's Hollow.
# Response from Model:  The provided text does not mention the quote written on James and Lily's grave in Godric's Hollow.
# iteration # 160 test
# Response from Model:  This text does not mention how the Death Eaters find Harry, Hermione, and Ron in the forest before they are taken to Malfoy Manor in the book Harry Potter and the Deathly Hallows.
# Response from Model:  This context does not mention anything about the Death Eaters finding Harry, Hermione, and Ron in the forest before they are taken to Malfoy Manor in the book Harry Potter and the Deathly Hallows, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention how the Death Eaters find Harry, Hermione, and Ron in the forest before they are taken to Malfoy Manor.
# iteration # 161 test
# Response from Model:  The provided text does not contain information about how Peter Pettigrew dies.
# Response from Model:  The provided text does not mention how Peter Pettigrew dies.
# Response from Model:  The provided text does not mention Peter Pettigrew's death, so I cannot answer this question.
# iteration # 162 test
# Response from Model:  The provided text does not mention anything about Ariana Dumbledore or why she stopped using magic.
# Response from Model:  The provided text does not contain any information about Ariana Dumbledore's reasons for stopping using magic.
# Response from Model:  The provided text does not mention anything about Ariana Dumbledore or the reason she stopped using magic.
# iteration # 163 test
# Response from Model:  This context does not mention anything about how to get into Ravenclaw's common room, so I cannot answer this question from the provided context.
# Response from Model:  The provided text does not mention Ravenclaw's common room or how to get into it.
# Response from Model:  The provided text does not contain any information on how to get into Ravenclaw's common room.
# iteration # 164 test
# Response from Model:  The provided text does not mention how Lily and Snape meet for the first time, so I cannot answer this question from the provided context.
# Response from Model:  The given text does not mention how Lily and Snape meet for the first time. So I can not answer this question from the provided information.
# Response from Model:  The given text does not provide information about how Lily and Snape first meet.

# %%
df_qa.columns
# Out:
# Index(['Question', 'Answer', 'i', 'j', 'k', 'pagewise_texts_v1',
#        'pagewise_texts_v2', 'pagewise_texts_v3', 'splitted_texts_v1',
#        'splitted_texts_v2', 'splitted_texts_v3', 'splitted_texts_chunks_v1',
#        'splitted_texts_chunks_v2', 'splitted_texts_chunks_v3', 'page_id_v1',
#        'page_id_v2', 'page_id_v3', 'combine_prompt_RAG1',
#        'combine_prompt_RAG2', 'combine_prompt_RAG3',
#        'Gemini_pro_model_output_v1', 'Gemini_pro_model_output_v2',
#        'Gemini_pro_model_output_v3', 'palm_bison32k_output_v1',
#        'palm_bison32k_output_v2', 'palm_bison32k_output_v3'],
#       dtype='object')

# %%
# Delete the 'col2' column
df_qa = df_qa.drop('combine_prompt_RAG1', axis=1)
df_qa = df_qa.drop('combine_prompt_RAG2', axis=1)
df_qa = df_qa.drop('combine_prompt_RAG3', axis=1)

output1 = "./results/harry_potte_qa_model_out.csv"

df_qa.to_csv(output1)

# %%
df_qa.head(1)

# %% [markdown]
# #### As we can see in the output above the poor search setup give a bad response
